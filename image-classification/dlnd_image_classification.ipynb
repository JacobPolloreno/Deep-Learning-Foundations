# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 2
sample_id = 50
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 2:
# Samples: 10000
# Label Counts: {0: 984, 1: 1007, 2: 1010, 3: 995, 4: 1010, 5: 988, 6: 1008, 7: 1026, 8: 987, 9: 985}
# First 20 Labels: [1, 6, 6, 8, 8, 3, 4, 6, 0, 6, 0, 3, 6, 6, 5, 4, 8, 3, 2, 6]
#
# Example of Image 50:
# Image - Min Value: 23 Max Value: 244
# Image - Shape: (32, 32, 3)
# Label - Label Id: 0 Name: airplane

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    return x / np.max(x)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    labels = np.zeros((10,10))
    np.fill_diagonal(labels,1)
    
    one_hot = np.zeros((len(x), 10))
    
    for i, sample in enumerate(x):
        one_hot[i] = labels[sample]
    
    return one_hot

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    return tf.placeholder(tf.float32, [None, image_shape[0], image_shape[1], image_shape[2]], name='x')


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    return tf.placeholder(tf.float32, [None, n_classes], name='y')


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    return tf.placeholder(tf.float32, name='keep_prob')


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    input_depth = x_tensor.get_shape().as_list()[-1]
    weight = tf.Variable(tf.truncated_normal([conv_ksize[0], conv_ksize[1],
                                           input_depth, conv_num_outputs],
                                          mean=0.0, stddev=0.1))
    bias = tf.Variable(tf.zeros(conv_num_outputs))
    
    

    def conv2d(x, W, b, strides):
        """
        Apply a 2d convolution to a x tensor
        :param x: Tensorflow x input
        :param W: weights applied to the convolution layer
        :param b: bias applied to convolution layer
        :parm strides: 2-D tuple specifying convolution kernel strides
        : return convolution of x tensor
        """
        x = tf.nn.conv2d(x, W, strides=[1, strides[0], strides[1], 1], padding='SAME')
        x = tf.nn.bias_add(x, b)
        x = tf.nn.relu(x)
        return x
    
    def maxpool2d(x, ksize, pstrides):
        """
        Apply max pooling to convoluted tensor using 2D kernel/stride
        :param x: convoluted tensor(output from conv2d())
        :param ksize: 2-D tuple for kernel size for pool
        :param strides: 2-D tuple for strides for pool
        : return max pooling of convoluted x tensor
        """
        return tf.nn.max_pool(conv, ksize=[1, ksize[0], ksize[1], 1],
                              strides=[1, pstrides[0], pstrides[1], 1], padding='SAME')
    
    
    # Apply convolution and nonlinear activation
    conv = conv2d(x_tensor, weight, bias, conv_strides)
    
    # Max Pooling Implementation
    conv = maxpool2d(conv, pool_ksize, pool_strides)
    return conv 


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    dim = x_tensor.get_shape().as_list()
    volume = dim[1] * dim[2] * dim[3]
    return tf.reshape(x_tensor, [-1, volume])


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    weights = tf.Variable(tf.truncated_normal([x_tensor.get_shape().as_list()[1], num_outputs],
                                              mean=0.0, stddev=0.1))
    bias = tf.Variable(tf.zeros(num_outputs))
    
    fully_conn = tf.add(tf.matmul(x_tensor, weights), bias)
    fully_conn = tf.nn.relu(fully_conn)
    return fully_conn


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    weights = tf.Variable(tf.truncated_normal([x_tensor.get_shape().as_list()[1], num_outputs],
                                              mean=0.0, stddev=0.1))
    bias = tf.Variable(tf.zeros(num_outputs))
    return tf.add(tf.matmul(x_tensor, weights), bias)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    print(x.get_shape())
    # Apply Convolution and Max Pool layers
    ## Layer 1 - 32x32x3 to x32
    conv1 = conv2d_maxpool(x, conv_num_outputs=16, conv_ksize=(3,3),
                           conv_strides=(1, 1), pool_ksize=(2,2), pool_strides=(2,2))
    print(conv1.get_shape())
    ## Layer 2 - x32 to  x64
    conv2 = conv2d_maxpool(conv1, conv_num_outputs=32, conv_ksize=(2,2),
                       conv_strides=(1, 1), pool_ksize=(1,1), pool_strides=(1,1))
    print(conv2.get_shape())
    conv3 = conv2d_maxpool(conv2, conv_num_outputs=64, conv_ksize=(2,2),
                       conv_strides=(1, 1), pool_ksize=(2,2), pool_strides=(2,2))
    print(conv3.get_shape())
    
    # Apply a Flatten Layer
    flat = flatten(conv3)

    # Apply Fully Connected Layers
    ## Fully connected layer
    fc1 = fully_conn(flat, num_outputs=2048)
    fc1 = tf.nn.dropout(fc1, keep_prob)
    fc2 = fully_conn(fc1, num_outputs=1024)
    fc2 = tf.nn.dropout(fc2, keep_prob)
    
    # Apply an Output Layer
    out = output(fc1, num_outputs=10)
    
    return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost) # default lr 0.001

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# (?, 32, 32, 3)
# (?, 16, 16, 16)
# (?, 16, 16, 32)
# (?, 8, 8, 64)
# (?, 32, 32, 3)
# (?, 16, 16, 16)
# (?, 16, 16, 32)
# (?, 8, 8, 64)
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_prob: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    
    # Run single optimization
    session.run(optimizer, feed_dict={x:feature_batch, y:label_batch, keep_prob:keep_probability})
    pass


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    
    # calculate batch loss and accuracy
    loss = session.run(cost, feed_dict={x:feature_batch, y:label_batch, keep_prob: 1.})
    valid_acc = session.run(accuracy, feed_dict={x:valid_features, y:valid_labels, keep_prob: 1.})
    
    print('Loss: {:>10.4f} Validation Accuracy: {:.6f}'.format(loss, valid_acc))
    pass

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# Tune Parameters
epochs = 100
batch_size = 5000
keep_probability = 0.3

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Loss:     4.9186 Validation Accuracy: 0.100600
# Epoch  2, CIFAR-10 Batch 1:  Loss:     3.2894 Validation Accuracy: 0.123200
# Epoch  3, CIFAR-10 Batch 1:  Loss:     2.3970 Validation Accuracy: 0.103000
# Epoch  4, CIFAR-10 Batch 1:  Loss:     2.3069 Validation Accuracy: 0.103800
# Epoch  5, CIFAR-10 Batch 1:  Loss:     2.2593 Validation Accuracy: 0.120200
# Epoch  6, CIFAR-10 Batch 1:  Loss:     2.1967 Validation Accuracy: 0.198400
# Epoch  7, CIFAR-10 Batch 1:  Loss:     2.1476 Validation Accuracy: 0.232800
# Epoch  8, CIFAR-10 Batch 1:  Loss:     2.1022 Validation Accuracy: 0.238400
# Epoch  9, CIFAR-10 Batch 1:  Loss:     2.0507 Validation Accuracy: 0.287200
# Epoch 10, CIFAR-10 Batch 1:  Loss:     1.9887 Validation Accuracy: 0.302800
# Epoch 11, CIFAR-10 Batch 1:  Loss:     1.9202 Validation Accuracy: 0.350400
# Epoch 12, CIFAR-10 Batch 1:  Loss:     1.8534 Validation Accuracy: 0.359200
# Epoch 13, CIFAR-10 Batch 1:  Loss:     1.7819 Validation Accuracy: 0.388000
# Epoch 14, CIFAR-10 Batch 1:  Loss:     1.7218 Validation Accuracy: 0.394400
# Epoch 15, CIFAR-10 Batch 1:  Loss:     1.6660 Validation Accuracy: 0.414800
# Epoch 16, CIFAR-10 Batch 1:  Loss:     1.6131 Validation Accuracy: 0.428200
# Epoch 17, CIFAR-10 Batch 1:  Loss:     1.5678 Validation Accuracy: 0.438200
# Epoch 18, CIFAR-10 Batch 1:  Loss:     1.5300 Validation Accuracy: 0.441600
# Epoch 19, CIFAR-10 Batch 1:  Loss:     1.5026 Validation Accuracy: 0.449400
# Epoch 20, CIFAR-10 Batch 1:  Loss:     1.4641 Validation Accuracy: 0.460400
# Epoch 21, CIFAR-10 Batch 1:  Loss:     1.4441 Validation Accuracy: 0.461600
# Epoch 22, CIFAR-10 Batch 1:  Loss:     1.4222 Validation Accuracy: 0.467200
# Epoch 23, CIFAR-10 Batch 1:  Loss:     1.3900 Validation Accuracy: 0.476200
# Epoch 24, CIFAR-10 Batch 1:  Loss:     1.3684 Validation Accuracy: 0.480200
# Epoch 25, CIFAR-10 Batch 1:  Loss:     1.3493 Validation Accuracy: 0.483600
# Epoch 26, CIFAR-10 Batch 1:  Loss:     1.3236 Validation Accuracy: 0.486000
# Epoch 27, CIFAR-10 Batch 1:  Loss:     1.3005 Validation Accuracy: 0.495600
# Epoch 28, CIFAR-10 Batch 1:  Loss:     1.2836 Validation Accuracy: 0.499200
# Epoch 29, CIFAR-10 Batch 1:  Loss:     1.2601 Validation Accuracy: 0.503800
# Epoch 30, CIFAR-10 Batch 1:  Loss:     1.2399 Validation Accuracy: 0.507400
# Epoch 31, CIFAR-10 Batch 1:  Loss:     1.2208 Validation Accuracy: 0.511400
# Epoch 32, CIFAR-10 Batch 1:  Loss:     1.1993 Validation Accuracy: 0.516200
# Epoch 33, CIFAR-10 Batch 1:  Loss:     1.1811 Validation Accuracy: 0.518000
# Epoch 34, CIFAR-10 Batch 1:  Loss:     1.1594 Validation Accuracy: 0.522600
# Epoch 35, CIFAR-10 Batch 1:  Loss:     1.1398 Validation Accuracy: 0.526600
# Epoch 36, CIFAR-10 Batch 1:  Loss:     1.1223 Validation Accuracy: 0.530200
# Epoch 37, CIFAR-10 Batch 1:  Loss:     1.1068 Validation Accuracy: 0.532400
# Epoch 38, CIFAR-10 Batch 1:  Loss:     1.0907 Validation Accuracy: 0.532400
# Epoch 39, CIFAR-10 Batch 1:  Loss:     1.0687 Validation Accuracy: 0.537600
# Epoch 40, CIFAR-10 Batch 1:  Loss:     1.0509 Validation Accuracy: 0.537800
# Epoch 41, CIFAR-10 Batch 1:  Loss:     1.0292 Validation Accuracy: 0.540800
# Epoch 42, CIFAR-10 Batch 1:  Loss:     1.0165 Validation Accuracy: 0.542800
# Epoch 43, CIFAR-10 Batch 1:  Loss:     1.0041 Validation Accuracy: 0.545600
# Epoch 44, CIFAR-10 Batch 1:  Loss:     0.9795 Validation Accuracy: 0.548600
# Epoch 45, CIFAR-10 Batch 1:  Loss:     0.9686 Validation Accuracy: 0.545200
# Epoch 46, CIFAR-10 Batch 1:  Loss:     0.9443 Validation Accuracy: 0.548800
# Epoch 47, CIFAR-10 Batch 1:  Loss:     0.9299 Validation Accuracy: 0.552200
# Epoch 48, CIFAR-10 Batch 1:  Loss:     0.9099 Validation Accuracy: 0.554600
# Epoch 49, CIFAR-10 Batch 1:  Loss:     0.8934 Validation Accuracy: 0.555000
# Epoch 50, CIFAR-10 Batch 1:  Loss:     0.8784 Validation Accuracy: 0.557400
# Epoch 51, CIFAR-10 Batch 1:  Loss:     0.8675 Validation Accuracy: 0.562400
# Epoch 52, CIFAR-10 Batch 1:  Loss:     0.8532 Validation Accuracy: 0.564600
# Epoch 53, CIFAR-10 Batch 1:  Loss:     0.8272 Validation Accuracy: 0.565200
# Epoch 54, CIFAR-10 Batch 1:  Loss:     0.8222 Validation Accuracy: 0.559600
# Epoch 55, CIFAR-10 Batch 1:  Loss:     0.7961 Validation Accuracy: 0.567600
# Epoch 56, CIFAR-10 Batch 1:  Loss:     0.7862 Validation Accuracy: 0.568600
# Epoch 57, CIFAR-10 Batch 1:  Loss:     0.7661 Validation Accuracy: 0.573200
# Epoch 58, CIFAR-10 Batch 1:  Loss:     0.7571 Validation Accuracy: 0.568400
# Epoch 59, CIFAR-10 Batch 1:  Loss:     0.7356 Validation Accuracy: 0.573400
# Epoch 60, CIFAR-10 Batch 1:  Loss:     0.7206 Validation Accuracy: 0.580600
# Epoch 61, CIFAR-10 Batch 1:  Loss:     0.7075 Validation Accuracy: 0.580000
# Epoch 62, CIFAR-10 Batch 1:  Loss:     0.6871 Validation Accuracy: 0.576800
# Epoch 63, CIFAR-10 Batch 1:  Loss:     0.6765 Validation Accuracy: 0.573800
# Epoch 64, CIFAR-10 Batch 1:  Loss:     0.6675 Validation Accuracy: 0.577400
# Epoch 65, CIFAR-10 Batch 1:  Loss:     0.6468 Validation Accuracy: 0.580800
# Epoch 66, CIFAR-10 Batch 1:  Loss:     0.6382 Validation Accuracy: 0.582200
# Epoch 67, CIFAR-10 Batch 1:  Loss:     0.6200 Validation Accuracy: 0.586800
# Epoch 68, CIFAR-10 Batch 1:  Loss:     0.6064 Validation Accuracy: 0.584000
# Epoch 69, CIFAR-10 Batch 1:  Loss:     0.5915 Validation Accuracy: 0.583000
# Epoch 70, CIFAR-10 Batch 1:  Loss:     0.5803 Validation Accuracy: 0.588600
# Epoch 71, CIFAR-10 Batch 1:  Loss:     0.5707 Validation Accuracy: 0.590400
# Epoch 72, CIFAR-10 Batch 1:  Loss:     0.5533 Validation Accuracy: 0.586400
# Epoch 73, CIFAR-10 Batch 1:  Loss:     0.5432 Validation Accuracy: 0.590000
# Epoch 74, CIFAR-10 Batch 1:  Loss:     0.5215 Validation Accuracy: 0.588800
# Epoch 75, CIFAR-10 Batch 1:  Loss:     0.5217 Validation Accuracy: 0.585800
# Epoch 76, CIFAR-10 Batch 1:  Loss:     0.5139 Validation Accuracy: 0.588000
# Epoch 77, CIFAR-10 Batch 1:  Loss:     0.4880 Validation Accuracy: 0.592600
# Epoch 78, CIFAR-10 Batch 1:  Loss:     0.4966 Validation Accuracy: 0.590800
# Epoch 79, CIFAR-10 Batch 1:  Loss:     0.4681 Validation Accuracy: 0.600000
# Epoch 80, CIFAR-10 Batch 1:  Loss:     0.4703 Validation Accuracy: 0.593000
# Epoch 81, CIFAR-10 Batch 1:  Loss:     0.4480 Validation Accuracy: 0.596600
# Epoch 82, CIFAR-10 Batch 1:  Loss:     0.4425 Validation Accuracy: 0.593800
# Epoch 83, CIFAR-10 Batch 1:  Loss:     0.4237 Validation Accuracy: 0.593400
# Epoch 84, CIFAR-10 Batch 1:  Loss:     0.4051 Validation Accuracy: 0.598200
# Epoch 85, CIFAR-10 Batch 1:  Loss:     0.3946 Validation Accuracy: 0.597400
# Epoch 86, CIFAR-10 Batch 1:  Loss:     0.3852 Validation Accuracy: 0.599800
# Epoch 87, CIFAR-10 Batch 1:  Loss:     0.3750 Validation Accuracy: 0.604000
# Epoch 88, CIFAR-10 Batch 1:  Loss:     0.3684 Validation Accuracy: 0.602400
# Epoch 89, CIFAR-10 Batch 1:  Loss:     0.3564 Validation Accuracy: 0.600800
# Epoch 90, CIFAR-10 Batch 1:  Loss:     0.3479 Validation Accuracy: 0.600600
# Epoch 91, CIFAR-10 Batch 1:  Loss:     0.3405 Validation Accuracy: 0.602000
# Epoch 92, CIFAR-10 Batch 1:  Loss:     0.3301 Validation Accuracy: 0.605600
# Epoch 93, CIFAR-10 Batch 1:  Loss:     0.3203 Validation Accuracy: 0.606600
# Epoch 94, CIFAR-10 Batch 1:  Loss:     0.3132 Validation Accuracy: 0.604400
# Epoch 95, CIFAR-10 Batch 1:  Loss:     0.3014 Validation Accuracy: 0.609600
# Epoch 96, CIFAR-10 Batch 1:  Loss:     0.2914 Validation Accuracy: 0.608400
# Epoch 97, CIFAR-10 Batch 1:  Loss:     0.2836 Validation Accuracy: 0.607200
# Epoch 98, CIFAR-10 Batch 1:  Loss:     0.2754 Validation Accuracy: 0.607000
# Epoch 99, CIFAR-10 Batch 1:  Loss:     0.2706 Validation Accuracy: 0.610200
# Epoch 100, CIFAR-10 Batch 1:  Loss:     0.2595 Validation Accuracy: 0.607400

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Loss:     2.5527 Validation Accuracy: 0.193600
# Epoch  1, CIFAR-10 Batch 2:  Loss:     2.2002 Validation Accuracy: 0.183800
# Epoch  1, CIFAR-10 Batch 3:  Loss:     2.1910 Validation Accuracy: 0.166600
# Epoch  1, CIFAR-10 Batch 4:  Loss:     2.1199 Validation Accuracy: 0.211000
# Epoch  1, CIFAR-10 Batch 5:  Loss:     2.0580 Validation Accuracy: 0.283000
# Epoch  2, CIFAR-10 Batch 1:  Loss:     1.9807 Validation Accuracy: 0.349200
# Epoch  2, CIFAR-10 Batch 2:  Loss:     1.9124 Validation Accuracy: 0.340800
# Epoch  2, CIFAR-10 Batch 3:  Loss:     1.8193 Validation Accuracy: 0.378200
# Epoch  2, CIFAR-10 Batch 4:  Loss:     1.7515 Validation Accuracy: 0.390400
# Epoch  2, CIFAR-10 Batch 5:  Loss:     1.7210 Validation Accuracy: 0.404000
# Epoch  3, CIFAR-10 Batch 1:  Loss:     1.6712 Validation Accuracy: 0.401800
# Epoch  3, CIFAR-10 Batch 2:  Loss:     1.6574 Validation Accuracy: 0.422400
# Epoch  3, CIFAR-10 Batch 3:  Loss:     1.6086 Validation Accuracy: 0.421600
# Epoch  3, CIFAR-10 Batch 4:  Loss:     1.5814 Validation Accuracy: 0.436600
# Epoch  3, CIFAR-10 Batch 5:  Loss:     1.5709 Validation Accuracy: 0.450800
# Epoch  4, CIFAR-10 Batch 1:  Loss:     1.5243 Validation Accuracy: 0.453000
# Epoch  4, CIFAR-10 Batch 2:  Loss:     1.5204 Validation Accuracy: 0.461400
# Epoch  4, CIFAR-10 Batch 3:  Loss:     1.4769 Validation Accuracy: 0.477400
# Epoch  4, CIFAR-10 Batch 4:  Loss:     1.4501 Validation Accuracy: 0.477800
# Epoch  4, CIFAR-10 Batch 5:  Loss:     1.4362 Validation Accuracy: 0.486400
# Epoch  5, CIFAR-10 Batch 1:  Loss:     1.4101 Validation Accuracy: 0.485000
# Epoch  5, CIFAR-10 Batch 2:  Loss:     1.4124 Validation Accuracy: 0.499800
# Epoch  5, CIFAR-10 Batch 3:  Loss:     1.3812 Validation Accuracy: 0.501600
# Epoch  5, CIFAR-10 Batch 4:  Loss:     1.3626 Validation Accuracy: 0.506000
# Epoch  5, CIFAR-10 Batch 5:  Loss:     1.3447 Validation Accuracy: 0.511000
# Epoch  6, CIFAR-10 Batch 1:  Loss:     1.3228 Validation Accuracy: 0.520600
# Epoch  6, CIFAR-10 Batch 2:  Loss:     1.3282 Validation Accuracy: 0.523400
# Epoch  6, CIFAR-10 Batch 3:  Loss:     1.2950 Validation Accuracy: 0.530200
# Epoch  6, CIFAR-10 Batch 4:  Loss:     1.2847 Validation Accuracy: 0.528400
# Epoch  6, CIFAR-10 Batch 5:  Loss:     1.2676 Validation Accuracy: 0.538200
# Epoch  7, CIFAR-10 Batch 1:  Loss:     1.2549 Validation Accuracy: 0.540600
# Epoch  7, CIFAR-10 Batch 2:  Loss:     1.2640 Validation Accuracy: 0.540400
# Epoch  7, CIFAR-10 Batch 3:  Loss:     1.2331 Validation Accuracy: 0.547000
# Epoch  7, CIFAR-10 Batch 4:  Loss:     1.2317 Validation Accuracy: 0.541800
# Epoch  7, CIFAR-10 Batch 5:  Loss:     1.2108 Validation Accuracy: 0.549600
# Epoch  8, CIFAR-10 Batch 1:  Loss:     1.1995 Validation Accuracy: 0.554600
# Epoch  8, CIFAR-10 Batch 2:  Loss:     1.2062 Validation Accuracy: 0.557800
# Epoch  8, CIFAR-10 Batch 3:  Loss:     1.1764 Validation Accuracy: 0.561400
# Epoch  8, CIFAR-10 Batch 4:  Loss:     1.1754 Validation Accuracy: 0.563200
# Epoch  8, CIFAR-10 Batch 5:  Loss:     1.1559 Validation Accuracy: 0.567200
# Epoch  9, CIFAR-10 Batch 1:  Loss:     1.1532 Validation Accuracy: 0.573800
# Epoch  9, CIFAR-10 Batch 2:  Loss:     1.1589 Validation Accuracy: 0.569000
# Epoch  9, CIFAR-10 Batch 3:  Loss:     1.1341 Validation Accuracy: 0.576400
# Epoch  9, CIFAR-10 Batch 4:  Loss:     1.1303 Validation Accuracy: 0.579000
# Epoch  9, CIFAR-10 Batch 5:  Loss:     1.1094 Validation Accuracy: 0.583200
# Epoch 10, CIFAR-10 Batch 1:  Loss:     1.1011 Validation Accuracy: 0.584200
# Epoch 10, CIFAR-10 Batch 2:  Loss:     1.1097 Validation Accuracy: 0.587200
# Epoch 10, CIFAR-10 Batch 3:  Loss:     1.0795 Validation Accuracy: 0.585400
# Epoch 10, CIFAR-10 Batch 4:  Loss:     1.0778 Validation Accuracy: 0.590800
# Epoch 10, CIFAR-10 Batch 5:  Loss:     1.0590 Validation Accuracy: 0.593800
# Epoch 11, CIFAR-10 Batch 1:  Loss:     1.0629 Validation Accuracy: 0.595200
# Epoch 11, CIFAR-10 Batch 2:  Loss:     1.0721 Validation Accuracy: 0.595400
# Epoch 11, CIFAR-10 Batch 3:  Loss:     1.0403 Validation Accuracy: 0.597200
# Epoch 11, CIFAR-10 Batch 4:  Loss:     1.0461 Validation Accuracy: 0.595400
# Epoch 11, CIFAR-10 Batch 5:  Loss:     1.0281 Validation Accuracy: 0.603800
# Epoch 12, CIFAR-10 Batch 1:  Loss:     1.0262 Validation Accuracy: 0.601800
# Epoch 12, CIFAR-10 Batch 2:  Loss:     1.0402 Validation Accuracy: 0.599600
# Epoch 12, CIFAR-10 Batch 3:  Loss:     1.0019 Validation Accuracy: 0.610600
# Epoch 12, CIFAR-10 Batch 4:  Loss:     1.0041 Validation Accuracy: 0.606800
# Epoch 12, CIFAR-10 Batch 5:  Loss:     0.9811 Validation Accuracy: 0.612000
# Epoch 13, CIFAR-10 Batch 1:  Loss:     0.9832 Validation Accuracy: 0.612800
# Epoch 13, CIFAR-10 Batch 2:  Loss:     0.9946 Validation Accuracy: 0.613000
# Epoch 13, CIFAR-10 Batch 3:  Loss:     0.9646 Validation Accuracy: 0.616400
# Epoch 13, CIFAR-10 Batch 4:  Loss:     0.9687 Validation Accuracy: 0.617200
# Epoch 13, CIFAR-10 Batch 5:  Loss:     0.9491 Validation Accuracy: 0.619400
# Epoch 14, CIFAR-10 Batch 1:  Loss:     0.9521 Validation Accuracy: 0.619400
# Epoch 14, CIFAR-10 Batch 2:  Loss:     0.9628 Validation Accuracy: 0.620600
# Epoch 14, CIFAR-10 Batch 3:  Loss:     0.9312 Validation Accuracy: 0.622600
# Epoch 14, CIFAR-10 Batch 4:  Loss:     0.9389 Validation Accuracy: 0.620200
# Epoch 14, CIFAR-10 Batch 5:  Loss:     0.9158 Validation Accuracy: 0.630800
# Epoch 15, CIFAR-10 Batch 1:  Loss:     0.9230 Validation Accuracy: 0.625000
# Epoch 15, CIFAR-10 Batch 2:  Loss:     0.9306 Validation Accuracy: 0.625800
# Epoch 15, CIFAR-10 Batch 3:  Loss:     0.9025 Validation Accuracy: 0.630200
# Epoch 15, CIFAR-10 Batch 4:  Loss:     0.9104 Validation Accuracy: 0.626200
# Epoch 15, CIFAR-10 Batch 5:  Loss:     0.8906 Validation Accuracy: 0.636200
# Epoch 16, CIFAR-10 Batch 1:  Loss:     0.8973 Validation Accuracy: 0.623000
# Epoch 16, CIFAR-10 Batch 2:  Loss:     0.8942 Validation Accuracy: 0.636000
# Epoch 16, CIFAR-10 Batch 3:  Loss:     0.8664 Validation Accuracy: 0.637800
# Epoch 16, CIFAR-10 Batch 4:  Loss:     0.8744 Validation Accuracy: 0.632200
# Epoch 16, CIFAR-10 Batch 5:  Loss:     0.8582 Validation Accuracy: 0.638400
# Epoch 17, CIFAR-10 Batch 1:  Loss:     0.8669 Validation Accuracy: 0.633800
# Epoch 17, CIFAR-10 Batch 2:  Loss:     0.8698 Validation Accuracy: 0.636600
# Epoch 17, CIFAR-10 Batch 3:  Loss:     0.8380 Validation Accuracy: 0.641000
# Epoch 17, CIFAR-10 Batch 4:  Loss:     0.8542 Validation Accuracy: 0.637600
# Epoch 17, CIFAR-10 Batch 5:  Loss:     0.8330 Validation Accuracy: 0.646000
# Epoch 18, CIFAR-10 Batch 1:  Loss:     0.8437 Validation Accuracy: 0.631800
# Epoch 18, CIFAR-10 Batch 2:  Loss:     0.8384 Validation Accuracy: 0.645200
# Epoch 18, CIFAR-10 Batch 3:  Loss:     0.8125 Validation Accuracy: 0.645600
# Epoch 18, CIFAR-10 Batch 4:  Loss:     0.8129 Validation Accuracy: 0.646400
# Epoch 18, CIFAR-10 Batch 5:  Loss:     0.8077 Validation Accuracy: 0.647000
# Epoch 19, CIFAR-10 Batch 1:  Loss:     0.8157 Validation Accuracy: 0.647800
# Epoch 19, CIFAR-10 Batch 2:  Loss:     0.8157 Validation Accuracy: 0.648600
# Epoch 19, CIFAR-10 Batch 3:  Loss:     0.7899 Validation Accuracy: 0.650600
# Epoch 19, CIFAR-10 Batch 4:  Loss:     0.7899 Validation Accuracy: 0.653200
# Epoch 19, CIFAR-10 Batch 5:  Loss:     0.7800 Validation Accuracy: 0.654600
# Epoch 20, CIFAR-10 Batch 1:  Loss:     0.7874 Validation Accuracy: 0.650600
# Epoch 20, CIFAR-10 Batch 2:  Loss:     0.7902 Validation Accuracy: 0.659400
# Epoch 20, CIFAR-10 Batch 3:  Loss:     0.7637 Validation Accuracy: 0.658600
# Epoch 20, CIFAR-10 Batch 4:  Loss:     0.7660 Validation Accuracy: 0.660000
# Epoch 20, CIFAR-10 Batch 5:  Loss:     0.7545 Validation Accuracy: 0.656600
# Epoch 21, CIFAR-10 Batch 1:  Loss:     0.7567 Validation Accuracy: 0.658400
# Epoch 21, CIFAR-10 Batch 2:  Loss:     0.7573 Validation Accuracy: 0.661000
# Epoch 21, CIFAR-10 Batch 3:  Loss:     0.7333 Validation Accuracy: 0.659600
# Epoch 21, CIFAR-10 Batch 4:  Loss:     0.7403 Validation Accuracy: 0.658400
# Epoch 21, CIFAR-10 Batch 5:  Loss:     0.7300 Validation Accuracy: 0.665400
# Epoch 22, CIFAR-10 Batch 1:  Loss:     0.7364 Validation Accuracy: 0.659400
# Epoch 22, CIFAR-10 Batch 2:  Loss:     0.7395 Validation Accuracy: 0.662400
# Epoch 22, CIFAR-10 Batch 3:  Loss:     0.7174 Validation Accuracy: 0.660000
# Epoch 22, CIFAR-10 Batch 4:  Loss:     0.7342 Validation Accuracy: 0.653400
# Epoch 22, CIFAR-10 Batch 5:  Loss:     0.7171 Validation Accuracy: 0.661200
# Epoch 23, CIFAR-10 Batch 1:  Loss:     0.7071 Validation Accuracy: 0.660800
# Epoch 23, CIFAR-10 Batch 2:  Loss:     0.7104 Validation Accuracy: 0.669200
# Epoch 23, CIFAR-10 Batch 3:  Loss:     0.7128 Validation Accuracy: 0.659800
# Epoch 23, CIFAR-10 Batch 4:  Loss:     0.7082 Validation Accuracy: 0.657600
# Epoch 23, CIFAR-10 Batch 5:  Loss:     0.6929 Validation Accuracy: 0.663200
# Epoch 24, CIFAR-10 Batch 1:  Loss:     0.6960 Validation Accuracy: 0.668400
# Epoch 24, CIFAR-10 Batch 2:  Loss:     0.7045 Validation Accuracy: 0.656400
# Epoch 24, CIFAR-10 Batch 3:  Loss:     0.6783 Validation Accuracy: 0.665200
# Epoch 24, CIFAR-10 Batch 4:  Loss:     0.6770 Validation Accuracy: 0.667200
# Epoch 24, CIFAR-10 Batch 5:  Loss:     0.6662 Validation Accuracy: 0.666800
# Epoch 25, CIFAR-10 Batch 1:  Loss:     0.6825 Validation Accuracy: 0.670800
# Epoch 25, CIFAR-10 Batch 2:  Loss:     0.6737 Validation Accuracy: 0.667800
# Epoch 25, CIFAR-10 Batch 3:  Loss:     0.6459 Validation Accuracy: 0.677000
# Epoch 25, CIFAR-10 Batch 4:  Loss:     0.6511 Validation Accuracy: 0.670200
# Epoch 25, CIFAR-10 Batch 5:  Loss:     0.6320 Validation Accuracy: 0.676600
# Epoch 26, CIFAR-10 Batch 1:  Loss:     0.6440 Validation Accuracy: 0.676400
# Epoch 26, CIFAR-10 Batch 2:  Loss:     0.6597 Validation Accuracy: 0.668600
# Epoch 26, CIFAR-10 Batch 3:  Loss:     0.6468 Validation Accuracy: 0.667800
# Epoch 26, CIFAR-10 Batch 4:  Loss:     0.6432 Validation Accuracy: 0.665800
# Epoch 26, CIFAR-10 Batch 5:  Loss:     0.6202 Validation Accuracy: 0.677000
# Epoch 27, CIFAR-10 Batch 1:  Loss:     0.6281 Validation Accuracy: 0.669000
# Epoch 27, CIFAR-10 Batch 2:  Loss:     0.6302 Validation Accuracy: 0.684000
# Epoch 27, CIFAR-10 Batch 3:  Loss:     0.6095 Validation Accuracy: 0.675600
# Epoch 27, CIFAR-10 Batch 4:  Loss:     0.6101 Validation Accuracy: 0.678000
# Epoch 27, CIFAR-10 Batch 5:  Loss:     0.5921 Validation Accuracy: 0.681400
# Epoch 28, CIFAR-10 Batch 1:  Loss:     0.5977 Validation Accuracy: 0.680600
# Epoch 28, CIFAR-10 Batch 2:  Loss:     0.5985 Validation Accuracy: 0.682000
# Epoch 28, CIFAR-10 Batch 3:  Loss:     0.5768 Validation Accuracy: 0.689600
# Epoch 28, CIFAR-10 Batch 4:  Loss:     0.5778 Validation Accuracy: 0.683200
# Epoch 28, CIFAR-10 Batch 5:  Loss:     0.5672 Validation Accuracy: 0.681200
# Epoch 29, CIFAR-10 Batch 1:  Loss:     0.5743 Validation Accuracy: 0.683000
# Epoch 29, CIFAR-10 Batch 2:  Loss:     0.5713 Validation Accuracy: 0.688200
# Epoch 29, CIFAR-10 Batch 3:  Loss:     0.5535 Validation Accuracy: 0.686400
# Epoch 29, CIFAR-10 Batch 4:  Loss:     0.5530 Validation Accuracy: 0.685800
# Epoch 29, CIFAR-10 Batch 5:  Loss:     0.5418 Validation Accuracy: 0.687600
# Epoch 30, CIFAR-10 Batch 1:  Loss:     0.5554 Validation Accuracy: 0.684600
# Epoch 30, CIFAR-10 Batch 2:  Loss:     0.5549 Validation Accuracy: 0.692200
# Epoch 30, CIFAR-10 Batch 3:  Loss:     0.5439 Validation Accuracy: 0.687600
# Epoch 30, CIFAR-10 Batch 4:  Loss:     0.5443 Validation Accuracy: 0.686600
# Epoch 30, CIFAR-10 Batch 5:  Loss:     0.5258 Validation Accuracy: 0.690600
# Epoch 31, CIFAR-10 Batch 1:  Loss:     0.5316 Validation Accuracy: 0.693600
# Epoch 31, CIFAR-10 Batch 2:  Loss:     0.5375 Validation Accuracy: 0.690400
# Epoch 31, CIFAR-10 Batch 3:  Loss:     0.5249 Validation Accuracy: 0.688000
# Epoch 31, CIFAR-10 Batch 4:  Loss:     0.5261 Validation Accuracy: 0.686600
# Epoch 31, CIFAR-10 Batch 5:  Loss:     0.5103 Validation Accuracy: 0.689600
# Epoch 32, CIFAR-10 Batch 1:  Loss:     0.5231 Validation Accuracy: 0.681600
# Epoch 32, CIFAR-10 Batch 2:  Loss:     0.5192 Validation Accuracy: 0.693800
# Epoch 32, CIFAR-10 Batch 3:  Loss:     0.5025 Validation Accuracy: 0.694600
# Epoch 32, CIFAR-10 Batch 4:  Loss:     0.5037 Validation Accuracy: 0.692400
# Epoch 32, CIFAR-10 Batch 5:  Loss:     0.4892 Validation Accuracy: 0.697000
# Epoch 33, CIFAR-10 Batch 1:  Loss:     0.5007 Validation Accuracy: 0.692400
# Epoch 33, CIFAR-10 Batch 2:  Loss:     0.5010 Validation Accuracy: 0.696800
# Epoch 33, CIFAR-10 Batch 3:  Loss:     0.4805 Validation Accuracy: 0.692200
# Epoch 33, CIFAR-10 Batch 4:  Loss:     0.4804 Validation Accuracy: 0.700600
# Epoch 33, CIFAR-10 Batch 5:  Loss:     0.4609 Validation Accuracy: 0.698400
# Epoch 34, CIFAR-10 Batch 1:  Loss:     0.4737 Validation Accuracy: 0.694600
# Epoch 34, CIFAR-10 Batch 2:  Loss:     0.4828 Validation Accuracy: 0.696000
# Epoch 34, CIFAR-10 Batch 3:  Loss:     0.4648 Validation Accuracy: 0.694800
# Epoch 34, CIFAR-10 Batch 4:  Loss:     0.4578 Validation Accuracy: 0.701400
# Epoch 34, CIFAR-10 Batch 5:  Loss:     0.4408 Validation Accuracy: 0.702600
# Epoch 35, CIFAR-10 Batch 1:  Loss:     0.4547 Validation Accuracy: 0.699200
# Epoch 35, CIFAR-10 Batch 2:  Loss:     0.4623 Validation Accuracy: 0.702000
# Epoch 35, CIFAR-10 Batch 3:  Loss:     0.4448 Validation Accuracy: 0.698600
# Epoch 35, CIFAR-10 Batch 4:  Loss:     0.4403 Validation Accuracy: 0.698400
# Epoch 35, CIFAR-10 Batch 5:  Loss:     0.4259 Validation Accuracy: 0.701800
# Epoch 36, CIFAR-10 Batch 1:  Loss:     0.4338 Validation Accuracy: 0.701200
# Epoch 36, CIFAR-10 Batch 2:  Loss:     0.4355 Validation Accuracy: 0.703800
# Epoch 36, CIFAR-10 Batch 3:  Loss:     0.4253 Validation Accuracy: 0.701400
# Epoch 36, CIFAR-10 Batch 4:  Loss:     0.4276 Validation Accuracy: 0.699000
# Epoch 36, CIFAR-10 Batch 5:  Loss:     0.4105 Validation Accuracy: 0.699400
# Epoch 37, CIFAR-10 Batch 1:  Loss:     0.4208 Validation Accuracy: 0.702800
# Epoch 37, CIFAR-10 Batch 2:  Loss:     0.4223 Validation Accuracy: 0.700800
# Epoch 37, CIFAR-10 Batch 3:  Loss:     0.4121 Validation Accuracy: 0.699000
# Epoch 37, CIFAR-10 Batch 4:  Loss:     0.4062 Validation Accuracy: 0.701600
# Epoch 37, CIFAR-10 Batch 5:  Loss:     0.3902 Validation Accuracy: 0.703800
# Epoch 38, CIFAR-10 Batch 1:  Loss:     0.4053 Validation Accuracy: 0.705600
# Epoch 38, CIFAR-10 Batch 2:  Loss:     0.4162 Validation Accuracy: 0.696400
# Epoch 38, CIFAR-10 Batch 3:  Loss:     0.3966 Validation Accuracy: 0.704800
# Epoch 38, CIFAR-10 Batch 4:  Loss:     0.3906 Validation Accuracy: 0.708600
# Epoch 38, CIFAR-10 Batch 5:  Loss:     0.3742 Validation Accuracy: 0.704200
# Epoch 39, CIFAR-10 Batch 1:  Loss:     0.3845 Validation Accuracy: 0.710800
# Epoch 39, CIFAR-10 Batch 2:  Loss:     0.3834 Validation Accuracy: 0.706600
# Epoch 39, CIFAR-10 Batch 3:  Loss:     0.3761 Validation Accuracy: 0.706400
# Epoch 39, CIFAR-10 Batch 4:  Loss:     0.3714 Validation Accuracy: 0.710600
# Epoch 39, CIFAR-10 Batch 5:  Loss:     0.3611 Validation Accuracy: 0.704400
# Epoch 40, CIFAR-10 Batch 1:  Loss:     0.3704 Validation Accuracy: 0.708800
# Epoch 40, CIFAR-10 Batch 2:  Loss:     0.3677 Validation Accuracy: 0.706800
# Epoch 40, CIFAR-10 Batch 3:  Loss:     0.3569 Validation Accuracy: 0.710400
# Epoch 40, CIFAR-10 Batch 4:  Loss:     0.3519 Validation Accuracy: 0.709000
# Epoch 40, CIFAR-10 Batch 5:  Loss:     0.3401 Validation Accuracy: 0.706400
# Epoch 41, CIFAR-10 Batch 1:  Loss:     0.3515 Validation Accuracy: 0.710600
# Epoch 41, CIFAR-10 Batch 2:  Loss:     0.3500 Validation Accuracy: 0.705400
# Epoch 41, CIFAR-10 Batch 3:  Loss:     0.3466 Validation Accuracy: 0.706400
# Epoch 41, CIFAR-10 Batch 4:  Loss:     0.3426 Validation Accuracy: 0.704000
# Epoch 41, CIFAR-10 Batch 5:  Loss:     0.3251 Validation Accuracy: 0.711400
# Epoch 42, CIFAR-10 Batch 1:  Loss:     0.3349 Validation Accuracy: 0.711200
# Epoch 42, CIFAR-10 Batch 2:  Loss:     0.3373 Validation Accuracy: 0.707800
# Epoch 42, CIFAR-10 Batch 3:  Loss:     0.3316 Validation Accuracy: 0.707000
# Epoch 42, CIFAR-10 Batch 4:  Loss:     0.3281 Validation Accuracy: 0.706200
# Epoch 42, CIFAR-10 Batch 5:  Loss:     0.3090 Validation Accuracy: 0.707000
# Epoch 43, CIFAR-10 Batch 1:  Loss:     0.3214 Validation Accuracy: 0.706400
# Epoch 43, CIFAR-10 Batch 2:  Loss:     0.3207 Validation Accuracy: 0.713600
# Epoch 43, CIFAR-10 Batch 3:  Loss:     0.3142 Validation Accuracy: 0.706600
# Epoch 43, CIFAR-10 Batch 4:  Loss:     0.3061 Validation Accuracy: 0.713800
# Epoch 43, CIFAR-10 Batch 5:  Loss:     0.2932 Validation Accuracy: 0.709800
# Epoch 44, CIFAR-10 Batch 1:  Loss:     0.3112 Validation Accuracy: 0.704200
# Epoch 44, CIFAR-10 Batch 2:  Loss:     0.3110 Validation Accuracy: 0.709000
# Epoch 44, CIFAR-10 Batch 3:  Loss:     0.3037 Validation Accuracy: 0.705800
# Epoch 44, CIFAR-10 Batch 4:  Loss:     0.2887 Validation Accuracy: 0.708800
# Epoch 44, CIFAR-10 Batch 5:  Loss:     0.2755 Validation Accuracy: 0.713400
# Epoch 45, CIFAR-10 Batch 1:  Loss:     0.2889 Validation Accuracy: 0.707000
# Epoch 45, CIFAR-10 Batch 2:  Loss:     0.2903 Validation Accuracy: 0.712000
# Epoch 45, CIFAR-10 Batch 3:  Loss:     0.2856 Validation Accuracy: 0.709200
# Epoch 45, CIFAR-10 Batch 4:  Loss:     0.2758 Validation Accuracy: 0.711000
# Epoch 45, CIFAR-10 Batch 5:  Loss:     0.2615 Validation Accuracy: 0.711800
# Epoch 46, CIFAR-10 Batch 1:  Loss:     0.2748 Validation Accuracy: 0.711600
# Epoch 46, CIFAR-10 Batch 2:  Loss:     0.2775 Validation Accuracy: 0.708000
# Epoch 46, CIFAR-10 Batch 3:  Loss:     0.2777 Validation Accuracy: 0.706800
# Epoch 46, CIFAR-10 Batch 4:  Loss:     0.2678 Validation Accuracy: 0.712000
# Epoch 46, CIFAR-10 Batch 5:  Loss:     0.2519 Validation Accuracy: 0.709600
# Epoch 47, CIFAR-10 Batch 1:  Loss:     0.2648 Validation Accuracy: 0.710600
# Epoch 47, CIFAR-10 Batch 2:  Loss:     0.2635 Validation Accuracy: 0.712600
# Epoch 47, CIFAR-10 Batch 3:  Loss:     0.2635 Validation Accuracy: 0.705400
# Epoch 47, CIFAR-10 Batch 4:  Loss:     0.2545 Validation Accuracy: 0.711400
# Epoch 47, CIFAR-10 Batch 5:  Loss:     0.2403 Validation Accuracy: 0.708400
# Epoch 48, CIFAR-10 Batch 1:  Loss:     0.2581 Validation Accuracy: 0.714200
# Epoch 48, CIFAR-10 Batch 2:  Loss:     0.2541 Validation Accuracy: 0.711800
# Epoch 48, CIFAR-10 Batch 3:  Loss:     0.2485 Validation Accuracy: 0.707800
# Epoch 48, CIFAR-10 Batch 4:  Loss:     0.2376 Validation Accuracy: 0.712600
# Epoch 48, CIFAR-10 Batch 5:  Loss:     0.2276 Validation Accuracy: 0.712800
# Epoch 49, CIFAR-10 Batch 1:  Loss:     0.2371 Validation Accuracy: 0.716600
# Epoch 49, CIFAR-10 Batch 2:  Loss:     0.2350 Validation Accuracy: 0.713800
# Epoch 49, CIFAR-10 Batch 3:  Loss:     0.2391 Validation Accuracy: 0.709000
# Epoch 49, CIFAR-10 Batch 4:  Loss:     0.2333 Validation Accuracy: 0.708200
# Epoch 49, CIFAR-10 Batch 5:  Loss:     0.2155 Validation Accuracy: 0.714200
# Epoch 50, CIFAR-10 Batch 1:  Loss:     0.2306 Validation Accuracy: 0.712400
# Epoch 50, CIFAR-10 Batch 2:  Loss:     0.2304 Validation Accuracy: 0.712600
# Epoch 50, CIFAR-10 Batch 3:  Loss:     0.2280 Validation Accuracy: 0.710200
# Epoch 50, CIFAR-10 Batch 4:  Loss:     0.2156 Validation Accuracy: 0.711000
# Epoch 50, CIFAR-10 Batch 5:  Loss:     0.2007 Validation Accuracy: 0.716600
# Epoch 51, CIFAR-10 Batch 1:  Loss:     0.2179 Validation Accuracy: 0.708400
# Epoch 51, CIFAR-10 Batch 2:  Loss:     0.2209 Validation Accuracy: 0.712000
# Epoch 51, CIFAR-10 Batch 3:  Loss:     0.2201 Validation Accuracy: 0.706000
# Epoch 51, CIFAR-10 Batch 4:  Loss:     0.2108 Validation Accuracy: 0.707600
# Epoch 51, CIFAR-10 Batch 5:  Loss:     0.1958 Validation Accuracy: 0.716600
# Epoch 52, CIFAR-10 Batch 1:  Loss:     0.2038 Validation Accuracy: 0.714400
# Epoch 52, CIFAR-10 Batch 2:  Loss:     0.2074 Validation Accuracy: 0.713800
# Epoch 52, CIFAR-10 Batch 3:  Loss:     0.2122 Validation Accuracy: 0.709600
# Epoch 52, CIFAR-10 Batch 4:  Loss:     0.2145 Validation Accuracy: 0.705400
# Epoch 52, CIFAR-10 Batch 5:  Loss:     0.2014 Validation Accuracy: 0.708600
# Epoch 53, CIFAR-10 Batch 1:  Loss:     0.2113 Validation Accuracy: 0.711200
# Epoch 53, CIFAR-10 Batch 2:  Loss:     0.2113 Validation Accuracy: 0.706600
# Epoch 53, CIFAR-10 Batch 3:  Loss:     0.2018 Validation Accuracy: 0.715000
# Epoch 53, CIFAR-10 Batch 4:  Loss:     0.1884 Validation Accuracy: 0.710400
# Epoch 53, CIFAR-10 Batch 5:  Loss:     0.1745 Validation Accuracy: 0.720000
# Epoch 54, CIFAR-10 Batch 1:  Loss:     0.1835 Validation Accuracy: 0.718800
# Epoch 54, CIFAR-10 Batch 2:  Loss:     0.1906 Validation Accuracy: 0.711000
# Epoch 54, CIFAR-10 Batch 3:  Loss:     0.1790 Validation Accuracy: 0.716200
# Epoch 54, CIFAR-10 Batch 4:  Loss:     0.1761 Validation Accuracy: 0.716200
# Epoch 54, CIFAR-10 Batch 5:  Loss:     0.1635 Validation Accuracy: 0.711000
# Epoch 55, CIFAR-10 Batch 1:  Loss:     0.1743 Validation Accuracy: 0.717000
# Epoch 55, CIFAR-10 Batch 2:  Loss:     0.1705 Validation Accuracy: 0.713800
# Epoch 55, CIFAR-10 Batch 3:  Loss:     0.1695 Validation Accuracy: 0.717200
# Epoch 55, CIFAR-10 Batch 4:  Loss:     0.1636 Validation Accuracy: 0.715000
# Epoch 55, CIFAR-10 Batch 5:  Loss:     0.1571 Validation Accuracy: 0.719000
# Epoch 56, CIFAR-10 Batch 1:  Loss:     0.1659 Validation Accuracy: 0.719600
# Epoch 56, CIFAR-10 Batch 2:  Loss:     0.1676 Validation Accuracy: 0.717600
# Epoch 56, CIFAR-10 Batch 3:  Loss:     0.1650 Validation Accuracy: 0.715200
# Epoch 56, CIFAR-10 Batch 4:  Loss:     0.1594 Validation Accuracy: 0.717200
# Epoch 56, CIFAR-10 Batch 5:  Loss:     0.1508 Validation Accuracy: 0.717000
# Epoch 57, CIFAR-10 Batch 1:  Loss:     0.1567 Validation Accuracy: 0.717200
# Epoch 57, CIFAR-10 Batch 2:  Loss:     0.1532 Validation Accuracy: 0.715800
# Epoch 57, CIFAR-10 Batch 3:  Loss:     0.1484 Validation Accuracy: 0.718600
# Epoch 57, CIFAR-10 Batch 4:  Loss:     0.1416 Validation Accuracy: 0.718200
# Epoch 57, CIFAR-10 Batch 5:  Loss:     0.1349 Validation Accuracy: 0.720800
# Epoch 58, CIFAR-10 Batch 1:  Loss:     0.1454 Validation Accuracy: 0.720000
# Epoch 58, CIFAR-10 Batch 2:  Loss:     0.1480 Validation Accuracy: 0.723600
# Epoch 58, CIFAR-10 Batch 3:  Loss:     0.1467 Validation Accuracy: 0.716000
# Epoch 58, CIFAR-10 Batch 4:  Loss:     0.1378 Validation Accuracy: 0.717200
# Epoch 58, CIFAR-10 Batch 5:  Loss:     0.1277 Validation Accuracy: 0.721800
# Epoch 59, CIFAR-10 Batch 1:  Loss:     0.1377 Validation Accuracy: 0.718000
# Epoch 59, CIFAR-10 Batch 2:  Loss:     0.1337 Validation Accuracy: 0.719600
# Epoch 59, CIFAR-10 Batch 3:  Loss:     0.1274 Validation Accuracy: 0.717600
# Epoch 59, CIFAR-10 Batch 4:  Loss:     0.1219 Validation Accuracy: 0.718000
# Epoch 59, CIFAR-10 Batch 5:  Loss:     0.1182 Validation Accuracy: 0.721800
# Epoch 60, CIFAR-10 Batch 1:  Loss:     0.1289 Validation Accuracy: 0.719800
# Epoch 60, CIFAR-10 Batch 2:  Loss:     0.1323 Validation Accuracy: 0.720600
# Epoch 60, CIFAR-10 Batch 3:  Loss:     0.1241 Validation Accuracy: 0.718000
# Epoch 60, CIFAR-10 Batch 4:  Loss:     0.1182 Validation Accuracy: 0.717200
# Epoch 60, CIFAR-10 Batch 5:  Loss:     0.1172 Validation Accuracy: 0.721800
# Epoch 61, CIFAR-10 Batch 1:  Loss:     0.1249 Validation Accuracy: 0.720600
# Epoch 61, CIFAR-10 Batch 2:  Loss:     0.1251 Validation Accuracy: 0.720800
# Epoch 61, CIFAR-10 Batch 3:  Loss:     0.1198 Validation Accuracy: 0.717600
# Epoch 61, CIFAR-10 Batch 4:  Loss:     0.1172 Validation Accuracy: 0.714200
# Epoch 61, CIFAR-10 Batch 5:  Loss:     0.1144 Validation Accuracy: 0.716200
# Epoch 62, CIFAR-10 Batch 1:  Loss:     0.1179 Validation Accuracy: 0.717800
# Epoch 62, CIFAR-10 Batch 2:  Loss:     0.1141 Validation Accuracy: 0.720200
# Epoch 62, CIFAR-10 Batch 3:  Loss:     0.1086 Validation Accuracy: 0.715200
# Epoch 62, CIFAR-10 Batch 4:  Loss:     0.1019 Validation Accuracy: 0.716400
# Epoch 62, CIFAR-10 Batch 5:  Loss:     0.0990 Validation Accuracy: 0.721600
# Epoch 63, CIFAR-10 Batch 1:  Loss:     0.1082 Validation Accuracy: 0.716600
# Epoch 63, CIFAR-10 Batch 2:  Loss:     0.1103 Validation Accuracy: 0.717800
# Epoch 63, CIFAR-10 Batch 3:  Loss:     0.1046 Validation Accuracy: 0.720600
# Epoch 63, CIFAR-10 Batch 4:  Loss:     0.0976 Validation Accuracy: 0.716800
# Epoch 63, CIFAR-10 Batch 5:  Loss:     0.0952 Validation Accuracy: 0.720000
# Epoch 64, CIFAR-10 Batch 1:  Loss:     0.1063 Validation Accuracy: 0.717800
# Epoch 64, CIFAR-10 Batch 2:  Loss:     0.1060 Validation Accuracy: 0.720400
# Epoch 64, CIFAR-10 Batch 3:  Loss:     0.1000 Validation Accuracy: 0.717000
# Epoch 64, CIFAR-10 Batch 4:  Loss:     0.0930 Validation Accuracy: 0.718400
# Epoch 64, CIFAR-10 Batch 5:  Loss:     0.0888 Validation Accuracy: 0.717000
# Epoch 65, CIFAR-10 Batch 1:  Loss:     0.0998 Validation Accuracy: 0.719800
# Epoch 65, CIFAR-10 Batch 2:  Loss:     0.1002 Validation Accuracy: 0.717800
# Epoch 65, CIFAR-10 Batch 3:  Loss:     0.0939 Validation Accuracy: 0.718000
# Epoch 65, CIFAR-10 Batch 4:  Loss:     0.0895 Validation Accuracy: 0.720400
# Epoch 65, CIFAR-10 Batch 5:  Loss:     0.0813 Validation Accuracy: 0.719600
# Epoch 66, CIFAR-10 Batch 1:  Loss:     0.0921 Validation Accuracy: 0.717400
# Epoch 66, CIFAR-10 Batch 2:  Loss:     0.0975 Validation Accuracy: 0.714800
# Epoch 66, CIFAR-10 Batch 3:  Loss:     0.0930 Validation Accuracy: 0.713800
# Epoch 66, CIFAR-10 Batch 4:  Loss:     0.0833 Validation Accuracy: 0.717000
# Epoch 66, CIFAR-10 Batch 5:  Loss:     0.0771 Validation Accuracy: 0.718200
# Epoch 67, CIFAR-10 Batch 1:  Loss:     0.0857 Validation Accuracy: 0.717000
# Epoch 67, CIFAR-10 Batch 2:  Loss:     0.0900 Validation Accuracy: 0.716800
# Epoch 67, CIFAR-10 Batch 3:  Loss:     0.0837 Validation Accuracy: 0.720200
# Epoch 67, CIFAR-10 Batch 4:  Loss:     0.0760 Validation Accuracy: 0.722800
# Epoch 67, CIFAR-10 Batch 5:  Loss:     0.0714 Validation Accuracy: 0.721200
# Epoch 68, CIFAR-10 Batch 1:  Loss:     0.0845 Validation Accuracy: 0.720000
# Epoch 68, CIFAR-10 Batch 2:  Loss:     0.0928 Validation Accuracy: 0.722200
# Epoch 68, CIFAR-10 Batch 3:  Loss:     0.0865 Validation Accuracy: 0.716800
# Epoch 68, CIFAR-10 Batch 4:  Loss:     0.0744 Validation Accuracy: 0.720200
# Epoch 68, CIFAR-10 Batch 5:  Loss:     0.0698 Validation Accuracy: 0.723800
# Epoch 69, CIFAR-10 Batch 1:  Loss:     0.0803 Validation Accuracy: 0.715600
# Epoch 69, CIFAR-10 Batch 2:  Loss:     0.0877 Validation Accuracy: 0.715000
# Epoch 69, CIFAR-10 Batch 3:  Loss:     0.0802 Validation Accuracy: 0.716800
# Epoch 69, CIFAR-10 Batch 4:  Loss:     0.0723 Validation Accuracy: 0.711800
# Epoch 69, CIFAR-10 Batch 5:  Loss:     0.0704 Validation Accuracy: 0.715200
# Epoch 70, CIFAR-10 Batch 1:  Loss:     0.0852 Validation Accuracy: 0.718600
# Epoch 70, CIFAR-10 Batch 2:  Loss:     0.0909 Validation Accuracy: 0.712600
# Epoch 70, CIFAR-10 Batch 3:  Loss:     0.0740 Validation Accuracy: 0.720800
# Epoch 70, CIFAR-10 Batch 4:  Loss:     0.0661 Validation Accuracy: 0.719600
# Epoch 70, CIFAR-10 Batch 5:  Loss:     0.0815 Validation Accuracy: 0.708800
# Epoch 71, CIFAR-10 Batch 1:  Loss:     0.0963 Validation Accuracy: 0.705600
# Epoch 71, CIFAR-10 Batch 2:  Loss:     0.0815 Validation Accuracy: 0.713800
# Epoch 71, CIFAR-10 Batch 3:  Loss:     0.0740 Validation Accuracy: 0.716400
# Epoch 71, CIFAR-10 Batch 4:  Loss:     0.0916 Validation Accuracy: 0.700400
# Epoch 71, CIFAR-10 Batch 5:  Loss:     0.0855 Validation Accuracy: 0.704000
# Epoch 72, CIFAR-10 Batch 1:  Loss:     0.0753 Validation Accuracy: 0.718000
# Epoch 72, CIFAR-10 Batch 2:  Loss:     0.1026 Validation Accuracy: 0.708400
# Epoch 72, CIFAR-10 Batch 3:  Loss:     0.1037 Validation Accuracy: 0.699400
# Epoch 72, CIFAR-10 Batch 4:  Loss:     0.0700 Validation Accuracy: 0.717400
# Epoch 72, CIFAR-10 Batch 5:  Loss:     0.0806 Validation Accuracy: 0.710800
# Epoch 73, CIFAR-10 Batch 1:  Loss:     0.0839 Validation Accuracy: 0.718400
# Epoch 73, CIFAR-10 Batch 2:  Loss:     0.0686 Validation Accuracy: 0.721800
# Epoch 73, CIFAR-10 Batch 3:  Loss:     0.0711 Validation Accuracy: 0.719800
# Epoch 73, CIFAR-10 Batch 4:  Loss:     0.0579 Validation Accuracy: 0.721400
# Epoch 73, CIFAR-10 Batch 5:  Loss:     0.0595 Validation Accuracy: 0.718200
# Epoch 74, CIFAR-10 Batch 1:  Loss:     0.0701 Validation Accuracy: 0.717600
# Epoch 74, CIFAR-10 Batch 2:  Loss:     0.0688 Validation Accuracy: 0.716800
# Epoch 74, CIFAR-10 Batch 3:  Loss:     0.0642 Validation Accuracy: 0.717000
# Epoch 74, CIFAR-10 Batch 4:  Loss:     0.0565 Validation Accuracy: 0.720800
# Epoch 74, CIFAR-10 Batch 5:  Loss:     0.0531 Validation Accuracy: 0.718200
# Epoch 75, CIFAR-10 Batch 1:  Loss:     0.0676 Validation Accuracy: 0.721200
# Epoch 75, CIFAR-10 Batch 2:  Loss:     0.0649 Validation Accuracy: 0.719000
# Epoch 75, CIFAR-10 Batch 3:  Loss:     0.0586 Validation Accuracy: 0.719400
# Epoch 75, CIFAR-10 Batch 4:  Loss:     0.0528 Validation Accuracy: 0.720000
# Epoch 75, CIFAR-10 Batch 5:  Loss:     0.0543 Validation Accuracy: 0.718200
# Epoch 76, CIFAR-10 Batch 1:  Loss:     0.0604 Validation Accuracy: 0.716200
# Epoch 76, CIFAR-10 Batch 2:  Loss:     0.0561 Validation Accuracy: 0.720000
# Epoch 76, CIFAR-10 Batch 3:  Loss:     0.0509 Validation Accuracy: 0.720800
# Epoch 76, CIFAR-10 Batch 4:  Loss:     0.0454 Validation Accuracy: 0.718200
# Epoch 76, CIFAR-10 Batch 5:  Loss:     0.0477 Validation Accuracy: 0.714800
# Epoch 77, CIFAR-10 Batch 1:  Loss:     0.0622 Validation Accuracy: 0.713600
# Epoch 77, CIFAR-10 Batch 2:  Loss:     0.0579 Validation Accuracy: 0.721400
# Epoch 77, CIFAR-10 Batch 3:  Loss:     0.0525 Validation Accuracy: 0.718000
# Epoch 77, CIFAR-10 Batch 4:  Loss:     0.0469 Validation Accuracy: 0.721400
# Epoch 77, CIFAR-10 Batch 5:  Loss:     0.0507 Validation Accuracy: 0.716200
# Epoch 78, CIFAR-10 Batch 1:  Loss:     0.0616 Validation Accuracy: 0.710000
# Epoch 78, CIFAR-10 Batch 2:  Loss:     0.0516 Validation Accuracy: 0.719400
# Epoch 78, CIFAR-10 Batch 3:  Loss:     0.0458 Validation Accuracy: 0.718200
# Epoch 78, CIFAR-10 Batch 4:  Loss:     0.0551 Validation Accuracy: 0.705400
# Epoch 78, CIFAR-10 Batch 5:  Loss:     0.0694 Validation Accuracy: 0.703200
# Epoch 79, CIFAR-10 Batch 1:  Loss:     0.0558 Validation Accuracy: 0.713000
# Epoch 79, CIFAR-10 Batch 2:  Loss:     0.0558 Validation Accuracy: 0.717400
# Epoch 79, CIFAR-10 Batch 3:  Loss:     0.0660 Validation Accuracy: 0.704800
# Epoch 79, CIFAR-10 Batch 4:  Loss:     0.0929 Validation Accuracy: 0.680800
# Epoch 79, CIFAR-10 Batch 5:  Loss:     0.0569 Validation Accuracy: 0.711400
# Epoch 80, CIFAR-10 Batch 1:  Loss:     0.0541 Validation Accuracy: 0.722000
# Epoch 80, CIFAR-10 Batch 2:  Loss:     0.0859 Validation Accuracy: 0.694600
# Epoch 80, CIFAR-10 Batch 3:  Loss:     0.0659 Validation Accuracy: 0.703000
# Epoch 80, CIFAR-10 Batch 4:  Loss:     0.0532 Validation Accuracy: 0.724400
# Epoch 80, CIFAR-10 Batch 5:  Loss:     0.0686 Validation Accuracy: 0.706800
# Epoch 81, CIFAR-10 Batch 1:  Loss:     0.0571 Validation Accuracy: 0.719600
# Epoch 81, CIFAR-10 Batch 2:  Loss:     0.0528 Validation Accuracy: 0.716000
# Epoch 81, CIFAR-10 Batch 3:  Loss:     0.0499 Validation Accuracy: 0.718400
# Epoch 81, CIFAR-10 Batch 4:  Loss:     0.0470 Validation Accuracy: 0.717800
# Epoch 81, CIFAR-10 Batch 5:  Loss:     0.0441 Validation Accuracy: 0.718200
# Epoch 82, CIFAR-10 Batch 1:  Loss:     0.0460 Validation Accuracy: 0.722200
# Epoch 82, CIFAR-10 Batch 2:  Loss:     0.0478 Validation Accuracy: 0.722000
# Epoch 82, CIFAR-10 Batch 3:  Loss:     0.0425 Validation Accuracy: 0.716200
# Epoch 82, CIFAR-10 Batch 4:  Loss:     0.0348 Validation Accuracy: 0.717600
# Epoch 82, CIFAR-10 Batch 5:  Loss:     0.0380 Validation Accuracy: 0.717800
# Epoch 83, CIFAR-10 Batch 1:  Loss:     0.0419 Validation Accuracy: 0.725200
# Epoch 83, CIFAR-10 Batch 2:  Loss:     0.0397 Validation Accuracy: 0.722800
# Epoch 83, CIFAR-10 Batch 3:  Loss:     0.0396 Validation Accuracy: 0.719600
# Epoch 83, CIFAR-10 Batch 4:  Loss:     0.0390 Validation Accuracy: 0.717600
# Epoch 83, CIFAR-10 Batch 5:  Loss:     0.0389 Validation Accuracy: 0.714000
# Epoch 84, CIFAR-10 Batch 1:  Loss:     0.0350 Validation Accuracy: 0.728400
# Epoch 84, CIFAR-10 Batch 2:  Loss:     0.0336 Validation Accuracy: 0.726400
# Epoch 84, CIFAR-10 Batch 3:  Loss:     0.0332 Validation Accuracy: 0.721000
# Epoch 84, CIFAR-10 Batch 4:  Loss:     0.0289 Validation Accuracy: 0.719800
# Epoch 84, CIFAR-10 Batch 5:  Loss:     0.0290 Validation Accuracy: 0.722600
# Epoch 85, CIFAR-10 Batch 1:  Loss:     0.0314 Validation Accuracy: 0.730200
# Epoch 85, CIFAR-10 Batch 2:  Loss:     0.0312 Validation Accuracy: 0.725200
# Epoch 85, CIFAR-10 Batch 3:  Loss:     0.0304 Validation Accuracy: 0.721600
# Epoch 85, CIFAR-10 Batch 4:  Loss:     0.0281 Validation Accuracy: 0.724200
# Epoch 85, CIFAR-10 Batch 5:  Loss:     0.0283 Validation Accuracy: 0.726200
# Epoch 86, CIFAR-10 Batch 1:  Loss:     0.0301 Validation Accuracy: 0.726400
# Epoch 86, CIFAR-10 Batch 2:  Loss:     0.0296 Validation Accuracy: 0.733200
# Epoch 86, CIFAR-10 Batch 3:  Loss:     0.0300 Validation Accuracy: 0.721200
# Epoch 86, CIFAR-10 Batch 4:  Loss:     0.0284 Validation Accuracy: 0.719600
# Epoch 86, CIFAR-10 Batch 5:  Loss:     0.0287 Validation Accuracy: 0.716000
# Epoch 87, CIFAR-10 Batch 1:  Loss:     0.0299 Validation Accuracy: 0.727000
# Epoch 87, CIFAR-10 Batch 2:  Loss:     0.0262 Validation Accuracy: 0.727400
# Epoch 87, CIFAR-10 Batch 3:  Loss:     0.0291 Validation Accuracy: 0.719200
# Epoch 87, CIFAR-10 Batch 4:  Loss:     0.0288 Validation Accuracy: 0.719600
# Epoch 87, CIFAR-10 Batch 5:  Loss:     0.0259 Validation Accuracy: 0.725400
# Epoch 88, CIFAR-10 Batch 1:  Loss:     0.0259 Validation Accuracy: 0.730400
# Epoch 88, CIFAR-10 Batch 2:  Loss:     0.0248 Validation Accuracy: 0.735600
# Epoch 88, CIFAR-10 Batch 3:  Loss:     0.0261 Validation Accuracy: 0.727800
# Epoch 88, CIFAR-10 Batch 4:  Loss:     0.0242 Validation Accuracy: 0.726800
# Epoch 88, CIFAR-10 Batch 5:  Loss:     0.0222 Validation Accuracy: 0.731000
# Epoch 89, CIFAR-10 Batch 1:  Loss:     0.0251 Validation Accuracy: 0.728600
# Epoch 89, CIFAR-10 Batch 2:  Loss:     0.0265 Validation Accuracy: 0.724000
# Epoch 89, CIFAR-10 Batch 3:  Loss:     0.0306 Validation Accuracy: 0.715600
# Epoch 89, CIFAR-10 Batch 4:  Loss:     0.0246 Validation Accuracy: 0.719200
# Epoch 89, CIFAR-10 Batch 5:  Loss:     0.0221 Validation Accuracy: 0.722600
# Epoch 90, CIFAR-10 Batch 1:  Loss:     0.0270 Validation Accuracy: 0.725200
# Epoch 90, CIFAR-10 Batch 2:  Loss:     0.0283 Validation Accuracy: 0.720200
# Epoch 90, CIFAR-10 Batch 3:  Loss:     0.0315 Validation Accuracy: 0.713000
# Epoch 90, CIFAR-10 Batch 4:  Loss:     0.0247 Validation Accuracy: 0.723200
# Epoch 90, CIFAR-10 Batch 5:  Loss:     0.0215 Validation Accuracy: 0.727000
# Epoch 91, CIFAR-10 Batch 1:  Loss:     0.0317 Validation Accuracy: 0.721800
# Epoch 91, CIFAR-10 Batch 2:  Loss:     0.0374 Validation Accuracy: 0.712600
# Epoch 91, CIFAR-10 Batch 3:  Loss:     0.0295 Validation Accuracy: 0.717600
# Epoch 91, CIFAR-10 Batch 4:  Loss:     0.0201 Validation Accuracy: 0.726800
# Epoch 91, CIFAR-10 Batch 5:  Loss:     0.0261 Validation Accuracy: 0.714400
# Epoch 92, CIFAR-10 Batch 1:  Loss:     0.0429 Validation Accuracy: 0.707000
# Epoch 92, CIFAR-10 Batch 2:  Loss:     0.0260 Validation Accuracy: 0.720200
# Epoch 92, CIFAR-10 Batch 3:  Loss:     0.0215 Validation Accuracy: 0.725800
# Epoch 92, CIFAR-10 Batch 4:  Loss:     0.0344 Validation Accuracy: 0.705200
# Epoch 92, CIFAR-10 Batch 5:  Loss:     0.0383 Validation Accuracy: 0.705200
# Epoch 93, CIFAR-10 Batch 1:  Loss:     0.0286 Validation Accuracy: 0.723000
# Epoch 93, CIFAR-10 Batch 2:  Loss:     0.0296 Validation Accuracy: 0.723400
# Epoch 93, CIFAR-10 Batch 3:  Loss:     0.0354 Validation Accuracy: 0.713000
# Epoch 93, CIFAR-10 Batch 4:  Loss:     0.0253 Validation Accuracy: 0.716200
# Epoch 93, CIFAR-10 Batch 5:  Loss:     0.0215 Validation Accuracy: 0.725200
# Epoch 94, CIFAR-10 Batch 1:  Loss:     0.0267 Validation Accuracy: 0.722400
# Epoch 94, CIFAR-10 Batch 2:  Loss:     0.0243 Validation Accuracy: 0.729000
# Epoch 94, CIFAR-10 Batch 3:  Loss:     0.0193 Validation Accuracy: 0.728800
# Epoch 94, CIFAR-10 Batch 4:  Loss:     0.0177 Validation Accuracy: 0.720000
# Epoch 94, CIFAR-10 Batch 5:  Loss:     0.0191 Validation Accuracy: 0.721200
# Epoch 95, CIFAR-10 Batch 1:  Loss:     0.0212 Validation Accuracy: 0.723200
# Epoch 95, CIFAR-10 Batch 2:  Loss:     0.0207 Validation Accuracy: 0.729600
# Epoch 95, CIFAR-10 Batch 3:  Loss:     0.0183 Validation Accuracy: 0.728200
# Epoch 95, CIFAR-10 Batch 4:  Loss:     0.0195 Validation Accuracy: 0.718200
# Epoch 95, CIFAR-10 Batch 5:  Loss:     0.0195 Validation Accuracy: 0.717000
# Epoch 96, CIFAR-10 Batch 1:  Loss:     0.0200 Validation Accuracy: 0.722000
# Epoch 96, CIFAR-10 Batch 2:  Loss:     0.0196 Validation Accuracy: 0.727200
# Epoch 96, CIFAR-10 Batch 3:  Loss:     0.0204 Validation Accuracy: 0.724000
# Epoch 96, CIFAR-10 Batch 4:  Loss:     0.0162 Validation Accuracy: 0.721600
# Epoch 96, CIFAR-10 Batch 5:  Loss:     0.0166 Validation Accuracy: 0.720600
# Epoch 97, CIFAR-10 Batch 1:  Loss:     0.0177 Validation Accuracy: 0.727000
# Epoch 97, CIFAR-10 Batch 2:  Loss:     0.0187 Validation Accuracy: 0.726000
# Epoch 97, CIFAR-10 Batch 3:  Loss:     0.0164 Validation Accuracy: 0.724800
# Epoch 97, CIFAR-10 Batch 4:  Loss:     0.0143 Validation Accuracy: 0.722600
# Epoch 97, CIFAR-10 Batch 5:  Loss:     0.0170 Validation Accuracy: 0.719000
# Epoch 98, CIFAR-10 Batch 1:  Loss:     0.0173 Validation Accuracy: 0.728800
# Epoch 98, CIFAR-10 Batch 2:  Loss:     0.0169 Validation Accuracy: 0.725600
# Epoch 98, CIFAR-10 Batch 3:  Loss:     0.0172 Validation Accuracy: 0.725000
# Epoch 98, CIFAR-10 Batch 4:  Loss:     0.0158 Validation Accuracy: 0.719400
# Epoch 98, CIFAR-10 Batch 5:  Loss:     0.0153 Validation Accuracy: 0.721200
# Epoch 99, CIFAR-10 Batch 1:  Loss:     0.0160 Validation Accuracy: 0.726000
# Epoch 99, CIFAR-10 Batch 2:  Loss:     0.0174 Validation Accuracy: 0.722800
# Epoch 99, CIFAR-10 Batch 3:  Loss:     0.0157 Validation Accuracy: 0.726000
# Epoch 99, CIFAR-10 Batch 4:  Loss:     0.0138 Validation Accuracy: 0.723200
# Epoch 99, CIFAR-10 Batch 5:  Loss:     0.0140 Validation Accuracy: 0.722600
# Epoch 100, CIFAR-10 Batch 1:  Loss:     0.0156 Validation Accuracy: 0.722600
# Epoch 100, CIFAR-10 Batch 2:  Loss:     0.0178 Validation Accuracy: 0.724400
# Epoch 100, CIFAR-10 Batch 3:  Loss:     0.0142 Validation Accuracy: 0.725000
# Epoch 100, CIFAR-10 Batch 4:  Loss:     0.0126 Validation Accuracy: 0.723000
# Epoch 100, CIFAR-10 Batch 5:  Loss:     0.0134 Validation Accuracy: 0.721200

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.7244998514652252

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
