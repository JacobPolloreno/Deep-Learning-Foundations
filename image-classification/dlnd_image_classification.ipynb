# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 2
sample_id = 50
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 2:
# Samples: 10000
# Label Counts: {0: 984, 1: 1007, 2: 1010, 3: 995, 4: 1010, 5: 988, 6: 1008, 7: 1026, 8: 987, 9: 985}
# First 20 Labels: [1, 6, 6, 8, 8, 3, 4, 6, 0, 6, 0, 3, 6, 6, 5, 4, 8, 3, 2, 6]
#
# Example of Image 50:
# Image - Min Value: 23 Max Value: 244
# Image - Shape: (32, 32, 3)
# Label - Label Id: 0 Name: airplane

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    return x / np.max(x)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    labels = np.zeros((10,10))
    np.fill_diagonal(labels,1)
    
    one_hot = np.zeros((len(x), 10))
    
    for i, sample in enumerate(x):
        one_hot[i] = labels[sample]
    
    return one_hot

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    return tf.placeholder(tf.float32, [None, image_shape[0], image_shape[1], image_shape[2]], name='x')


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    return tf.placeholder(tf.float32, [None, n_classes], name='y')


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    return tf.placeholder(tf.float32, name='keep_prob')


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    input_depth = x_tensor.get_shape().as_list()[-1]
    weight = tf.Variable(tf.truncated_normal([conv_ksize[0], conv_ksize[1],
                                           input_depth, conv_num_outputs],
                                          mean=0.0, stddev=0.1))
    bias = tf.Variable(tf.zeros(conv_num_outputs))
    
    

    def conv2d(x, W, b, strides):
        """
        Apply a 2d convolution to a x tensor
        :param x: Tensorflow x input
        :param W: weights applied to the convolution layer
        :param b: bias applied to convolution layer
        :parm strides: 2-D tuple specifying convolution kernel strides
        : return convolution of x tensor
        """
        x = tf.nn.conv2d(x, W, strides=[1, strides[0], strides[1], 1], padding='SAME')
        x = tf.nn.bias_add(x, b)
        x = tf.nn.relu(x)
        return x
    
    def maxpool2d(x, ksize, pstrides):
        """
        Apply max pooling to convoluted tensor using 2D kernel/stride
        :param x: convoluted tensor(output from conv2d())
        :param ksize: 2-D tuple for kernel size for pool
        :param strides: 2-D tuple for strides for pool
        : return max pooling of convoluted x tensor
        """
        return tf.nn.max_pool(conv, ksize=[1, ksize[0], ksize[1], 1],
                              strides=[1, pstrides[0], pstrides[1], 1], padding='SAME')
    
    
    # Apply convolution and nonlinear activation
    conv = conv2d(x_tensor, weight, bias, conv_strides)
    
    # Max Pooling Implementation
    conv = maxpool2d(conv, pool_ksize, pool_strides)
    return conv 


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    dim = x_tensor.get_shape().as_list()
    volume = dim[1] * dim[2] * dim[3]
    return tf.reshape(x_tensor, [-1, volume])


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    weights = tf.Variable(tf.truncated_normal([x_tensor.get_shape().as_list()[1], num_outputs],
                                              mean=0.0, stddev=0.1))
    bias = tf.Variable(tf.zeros(num_outputs))
    
    fully_conn = tf.add(tf.matmul(x_tensor, weights), bias)
    fully_conn = tf.nn.relu(fully_conn)
    return fully_conn


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    weights = tf.Variable(tf.truncated_normal([x_tensor.get_shape().as_list()[1], num_outputs],
                                              mean=0.0, stddev=0.1))
    bias = tf.Variable(tf.zeros(num_outputs))
    return tf.add(tf.matmul(x_tensor, weights), bias)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    print(x.get_shape())
    # Apply Convolution and Max Pool layers
    ## Layer 1 - 32x32x3 to x32
    conv1 = conv2d_maxpool(x, conv_num_outputs=16, conv_ksize=(3,3),
                           conv_strides=(1, 1), pool_ksize=(2,2), pool_strides=(2,2))
    print(conv1.get_shape())
    ## Layer 2 - x32 to  x64
    conv2 = conv2d_maxpool(conv1, conv_num_outputs=32, conv_ksize=(2,2),
                       conv_strides=(1, 1), pool_ksize=(2,2), pool_strides=(2,2))
    print(conv2.get_shape())
    conv3 = conv2d_maxpool(conv2, conv_num_outputs=64, conv_ksize=(2,2),
                       conv_strides=(1, 1), pool_ksize=(2,2), pool_strides=(2,2))
    print(conv3.get_shape())
    
    # Apply a Flatten Layer
    flat = flatten(conv3)

    # Apply Fully Connected Layers
    ## Fully connected layer
    fc1 = fully_conn(flat, num_outputs=2048)
    fc1 = tf.nn.dropout(fc1, keep_prob)
    fc2 = fully_conn(fc1, num_outputs=1024)
    fc2 = tf.nn.dropout(fc2, keep_prob)
    
    # Apply an Output Layer
    out = output(fc1, num_outputs=10)
    
    return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost) # default lr 0.001

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# (?, 32, 32, 3)
# (?, 16, 16, 16)
# (?, 8, 8, 32)
# (?, 4, 4, 64)
# (?, 32, 32, 3)
# (?, 16, 16, 16)
# (?, 8, 8, 32)
# (?, 4, 4, 64)
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_prob: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    
    # Run single optimization
    session.run(optimizer, feed_dict={x:feature_batch, y:label_batch, keep_prob:keep_probability})
    pass


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    
    # calculate batch loss and accuracy
    loss = session.run(cost, feed_dict={x:feature_batch, y:label_batch, keep_prob: 1.})
    valid_acc = session.run(accuracy, feed_dict={x:valid_features, y:valid_labels, keep_prob: 1.})
    
    print('Loss: {:>10.4f} Validation Accuracy: {:.6f}'.format(loss, valid_acc))
    pass

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# Tune Parameters
epochs = 100
batch_size = 5000
keep_probability = 0.3

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Loss:     2.3069 Validation Accuracy: 0.119600
# Epoch  2, CIFAR-10 Batch 1:  Loss:     2.2214 Validation Accuracy: 0.204400
# Epoch  3, CIFAR-10 Batch 1:  Loss:     2.1945 Validation Accuracy: 0.218400
# Epoch  4, CIFAR-10 Batch 1:  Loss:     2.1541 Validation Accuracy: 0.291400
# Epoch  5, CIFAR-10 Batch 1:  Loss:     2.1012 Validation Accuracy: 0.336800
# Epoch  6, CIFAR-10 Batch 1:  Loss:     2.0407 Validation Accuracy: 0.347000
# Epoch  7, CIFAR-10 Batch 1:  Loss:     1.9642 Validation Accuracy: 0.369400
# Epoch  8, CIFAR-10 Batch 1:  Loss:     1.8783 Validation Accuracy: 0.379800
# Epoch  9, CIFAR-10 Batch 1:  Loss:     1.7914 Validation Accuracy: 0.389400
# Epoch 10, CIFAR-10 Batch 1:  Loss:     1.7208 Validation Accuracy: 0.401600
# Epoch 11, CIFAR-10 Batch 1:  Loss:     1.6676 Validation Accuracy: 0.410800
# Epoch 12, CIFAR-10 Batch 1:  Loss:     1.6272 Validation Accuracy: 0.411200
# Epoch 13, CIFAR-10 Batch 1:  Loss:     1.6020 Validation Accuracy: 0.421800
# Epoch 14, CIFAR-10 Batch 1:  Loss:     1.5730 Validation Accuracy: 0.431600
# Epoch 15, CIFAR-10 Batch 1:  Loss:     1.5500 Validation Accuracy: 0.440200
# Epoch 16, CIFAR-10 Batch 1:  Loss:     1.5267 Validation Accuracy: 0.447000
# Epoch 17, CIFAR-10 Batch 1:  Loss:     1.5009 Validation Accuracy: 0.456400
# Epoch 18, CIFAR-10 Batch 1:  Loss:     1.4751 Validation Accuracy: 0.461600
# Epoch 19, CIFAR-10 Batch 1:  Loss:     1.4488 Validation Accuracy: 0.472400
# Epoch 20, CIFAR-10 Batch 1:  Loss:     1.4240 Validation Accuracy: 0.475400
# Epoch 21, CIFAR-10 Batch 1:  Loss:     1.4005 Validation Accuracy: 0.483800
# Epoch 22, CIFAR-10 Batch 1:  Loss:     1.3798 Validation Accuracy: 0.484600
# Epoch 23, CIFAR-10 Batch 1:  Loss:     1.3585 Validation Accuracy: 0.490400
# Epoch 24, CIFAR-10 Batch 1:  Loss:     1.3366 Validation Accuracy: 0.498600
# Epoch 25, CIFAR-10 Batch 1:  Loss:     1.3149 Validation Accuracy: 0.502000
# Epoch 26, CIFAR-10 Batch 1:  Loss:     1.2974 Validation Accuracy: 0.507000
# Epoch 27, CIFAR-10 Batch 1:  Loss:     1.2858 Validation Accuracy: 0.509600
# Epoch 28, CIFAR-10 Batch 1:  Loss:     1.2629 Validation Accuracy: 0.513600
# Epoch 29, CIFAR-10 Batch 1:  Loss:     1.2484 Validation Accuracy: 0.518600
# Epoch 30, CIFAR-10 Batch 1:  Loss:     1.2280 Validation Accuracy: 0.524800
# Epoch 31, CIFAR-10 Batch 1:  Loss:     1.2191 Validation Accuracy: 0.526600
# Epoch 32, CIFAR-10 Batch 1:  Loss:     1.1987 Validation Accuracy: 0.534800
# Epoch 33, CIFAR-10 Batch 1:  Loss:     1.1881 Validation Accuracy: 0.527000
# Epoch 34, CIFAR-10 Batch 1:  Loss:     1.1724 Validation Accuracy: 0.540800
# Epoch 35, CIFAR-10 Batch 1:  Loss:     1.1504 Validation Accuracy: 0.543600
# Epoch 36, CIFAR-10 Batch 1:  Loss:     1.1373 Validation Accuracy: 0.545400
# Epoch 37, CIFAR-10 Batch 1:  Loss:     1.1260 Validation Accuracy: 0.548800
# Epoch 38, CIFAR-10 Batch 1:  Loss:     1.1096 Validation Accuracy: 0.551200
# Epoch 39, CIFAR-10 Batch 1:  Loss:     1.0942 Validation Accuracy: 0.555000
# Epoch 40, CIFAR-10 Batch 1:  Loss:     1.0838 Validation Accuracy: 0.558800
# Epoch 41, CIFAR-10 Batch 1:  Loss:     1.0721 Validation Accuracy: 0.556800
# Epoch 42, CIFAR-10 Batch 1:  Loss:     1.0556 Validation Accuracy: 0.559800
# Epoch 43, CIFAR-10 Batch 1:  Loss:     1.0501 Validation Accuracy: 0.561800
# Epoch 44, CIFAR-10 Batch 1:  Loss:     1.0356 Validation Accuracy: 0.562600
# Epoch 45, CIFAR-10 Batch 1:  Loss:     1.0233 Validation Accuracy: 0.562800
# Epoch 46, CIFAR-10 Batch 1:  Loss:     1.0075 Validation Accuracy: 0.566200
# Epoch 47, CIFAR-10 Batch 1:  Loss:     0.9961 Validation Accuracy: 0.567600
# Epoch 48, CIFAR-10 Batch 1:  Loss:     0.9856 Validation Accuracy: 0.574000
# Epoch 49, CIFAR-10 Batch 1:  Loss:     0.9708 Validation Accuracy: 0.576800
# Epoch 50, CIFAR-10 Batch 1:  Loss:     0.9636 Validation Accuracy: 0.578600
# Epoch 51, CIFAR-10 Batch 1:  Loss:     0.9542 Validation Accuracy: 0.576200
# Epoch 52, CIFAR-10 Batch 1:  Loss:     0.9389 Validation Accuracy: 0.577400
# Epoch 53, CIFAR-10 Batch 1:  Loss:     0.9361 Validation Accuracy: 0.578800
# Epoch 54, CIFAR-10 Batch 1:  Loss:     0.9209 Validation Accuracy: 0.577000
# Epoch 55, CIFAR-10 Batch 1:  Loss:     0.9059 Validation Accuracy: 0.581400
# Epoch 56, CIFAR-10 Batch 1:  Loss:     0.9011 Validation Accuracy: 0.584600
# Epoch 57, CIFAR-10 Batch 1:  Loss:     0.8889 Validation Accuracy: 0.583400
# Epoch 58, CIFAR-10 Batch 1:  Loss:     0.8735 Validation Accuracy: 0.586600
# Epoch 59, CIFAR-10 Batch 1:  Loss:     0.8712 Validation Accuracy: 0.586600
# Epoch 60, CIFAR-10 Batch 1:  Loss:     0.8677 Validation Accuracy: 0.579400
# Epoch 61, CIFAR-10 Batch 1:  Loss:     0.8418 Validation Accuracy: 0.588200
# Epoch 62, CIFAR-10 Batch 1:  Loss:     0.8481 Validation Accuracy: 0.586600
# Epoch 63, CIFAR-10 Batch 1:  Loss:     0.8449 Validation Accuracy: 0.579400
# Epoch 64, CIFAR-10 Batch 1:  Loss:     0.8233 Validation Accuracy: 0.592400
# Epoch 65, CIFAR-10 Batch 1:  Loss:     0.8106 Validation Accuracy: 0.590400
# Epoch 66, CIFAR-10 Batch 1:  Loss:     0.8003 Validation Accuracy: 0.592800
# Epoch 67, CIFAR-10 Batch 1:  Loss:     0.7935 Validation Accuracy: 0.588200
# Epoch 68, CIFAR-10 Batch 1:  Loss:     0.7803 Validation Accuracy: 0.592200
# Epoch 69, CIFAR-10 Batch 1:  Loss:     0.7652 Validation Accuracy: 0.597400
# Epoch 70, CIFAR-10 Batch 1:  Loss:     0.7537 Validation Accuracy: 0.595000
# Epoch 71, CIFAR-10 Batch 1:  Loss:     0.7459 Validation Accuracy: 0.595200
# Epoch 72, CIFAR-10 Batch 1:  Loss:     0.7381 Validation Accuracy: 0.594200
# Epoch 73, CIFAR-10 Batch 1:  Loss:     0.7294 Validation Accuracy: 0.596600
# Epoch 74, CIFAR-10 Batch 1:  Loss:     0.7184 Validation Accuracy: 0.597000
# Epoch 75, CIFAR-10 Batch 1:  Loss:     0.7074 Validation Accuracy: 0.597800
# Epoch 76, CIFAR-10 Batch 1:  Loss:     0.6996 Validation Accuracy: 0.600400
# Epoch 77, CIFAR-10 Batch 1:  Loss:     0.6965 Validation Accuracy: 0.598800
# Epoch 78, CIFAR-10 Batch 1:  Loss:     0.6911 Validation Accuracy: 0.597000
# Epoch 79, CIFAR-10 Batch 1:  Loss:     0.6787 Validation Accuracy: 0.598400
# Epoch 80, CIFAR-10 Batch 1:  Loss:     0.6665 Validation Accuracy: 0.600600
# Epoch 81, CIFAR-10 Batch 1:  Loss:     0.6565 Validation Accuracy: 0.603200
# Epoch 82, CIFAR-10 Batch 1:  Loss:     0.6481 Validation Accuracy: 0.601000
# Epoch 83, CIFAR-10 Batch 1:  Loss:     0.6399 Validation Accuracy: 0.605200
# Epoch 84, CIFAR-10 Batch 1:  Loss:     0.6311 Validation Accuracy: 0.604200
# Epoch 85, CIFAR-10 Batch 1:  Loss:     0.6197 Validation Accuracy: 0.603200
# Epoch 86, CIFAR-10 Batch 1:  Loss:     0.6123 Validation Accuracy: 0.605600
# Epoch 87, CIFAR-10 Batch 1:  Loss:     0.6047 Validation Accuracy: 0.606000
# Epoch 88, CIFAR-10 Batch 1:  Loss:     0.5962 Validation Accuracy: 0.603400
# Epoch 89, CIFAR-10 Batch 1:  Loss:     0.5875 Validation Accuracy: 0.605600
# Epoch 90, CIFAR-10 Batch 1:  Loss:     0.5785 Validation Accuracy: 0.604200
# Epoch 91, CIFAR-10 Batch 1:  Loss:     0.5702 Validation Accuracy: 0.607200
# Epoch 92, CIFAR-10 Batch 1:  Loss:     0.5644 Validation Accuracy: 0.608000
# Epoch 93, CIFAR-10 Batch 1:  Loss:     0.5543 Validation Accuracy: 0.608000
# Epoch 94, CIFAR-10 Batch 1:  Loss:     0.5489 Validation Accuracy: 0.603600
# Epoch 95, CIFAR-10 Batch 1:  Loss:     0.5487 Validation Accuracy: 0.605600
# Epoch 96, CIFAR-10 Batch 1:  Loss:     0.5353 Validation Accuracy: 0.604000
# Epoch 97, CIFAR-10 Batch 1:  Loss:     0.5345 Validation Accuracy: 0.609200
# Epoch 98, CIFAR-10 Batch 1:  Loss:     0.5271 Validation Accuracy: 0.612200
# Epoch 99, CIFAR-10 Batch 1:  Loss:     0.5162 Validation Accuracy: 0.606600
# Epoch 100, CIFAR-10 Batch 1:  Loss:     0.5092 Validation Accuracy: 0.606200

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Loss:     2.2807 Validation Accuracy: 0.121800
# Epoch  1, CIFAR-10 Batch 2:  Loss:     2.2234 Validation Accuracy: 0.244800
# Epoch  1, CIFAR-10 Batch 3:  Loss:     2.1813 Validation Accuracy: 0.259000
# Epoch  1, CIFAR-10 Batch 4:  Loss:     2.1308 Validation Accuracy: 0.287800
# Epoch  1, CIFAR-10 Batch 5:  Loss:     2.0686 Validation Accuracy: 0.299000
# Epoch  2, CIFAR-10 Batch 1:  Loss:     1.9809 Validation Accuracy: 0.331400
# Epoch  2, CIFAR-10 Batch 2:  Loss:     1.9224 Validation Accuracy: 0.364000
# Epoch  2, CIFAR-10 Batch 3:  Loss:     1.8291 Validation Accuracy: 0.382800
# Epoch  2, CIFAR-10 Batch 4:  Loss:     1.7726 Validation Accuracy: 0.380600
# Epoch  2, CIFAR-10 Batch 5:  Loss:     1.7508 Validation Accuracy: 0.392200
# Epoch  3, CIFAR-10 Batch 1:  Loss:     1.6949 Validation Accuracy: 0.397800
# Epoch  3, CIFAR-10 Batch 2:  Loss:     1.7015 Validation Accuracy: 0.408600
# Epoch  3, CIFAR-10 Batch 3:  Loss:     1.6467 Validation Accuracy: 0.416000
# Epoch  3, CIFAR-10 Batch 4:  Loss:     1.6097 Validation Accuracy: 0.433600
# Epoch  3, CIFAR-10 Batch 5:  Loss:     1.5845 Validation Accuracy: 0.445600
# Epoch  4, CIFAR-10 Batch 1:  Loss:     1.5488 Validation Accuracy: 0.453200
# Epoch  4, CIFAR-10 Batch 2:  Loss:     1.5554 Validation Accuracy: 0.459800
# Epoch  4, CIFAR-10 Batch 3:  Loss:     1.5137 Validation Accuracy: 0.461000
# Epoch  4, CIFAR-10 Batch 4:  Loss:     1.5007 Validation Accuracy: 0.470800
# Epoch  4, CIFAR-10 Batch 5:  Loss:     1.4813 Validation Accuracy: 0.474000
# Epoch  5, CIFAR-10 Batch 1:  Loss:     1.4655 Validation Accuracy: 0.477000
# Epoch  5, CIFAR-10 Batch 2:  Loss:     1.4704 Validation Accuracy: 0.482800
# Epoch  5, CIFAR-10 Batch 3:  Loss:     1.4393 Validation Accuracy: 0.486800
# Epoch  5, CIFAR-10 Batch 4:  Loss:     1.4327 Validation Accuracy: 0.487400
# Epoch  5, CIFAR-10 Batch 5:  Loss:     1.4053 Validation Accuracy: 0.500000
# Epoch  6, CIFAR-10 Batch 1:  Loss:     1.3877 Validation Accuracy: 0.504400
# Epoch  6, CIFAR-10 Batch 2:  Loss:     1.3960 Validation Accuracy: 0.502200
# Epoch  6, CIFAR-10 Batch 3:  Loss:     1.3776 Validation Accuracy: 0.511000
# Epoch  6, CIFAR-10 Batch 4:  Loss:     1.3713 Validation Accuracy: 0.511000
# Epoch  6, CIFAR-10 Batch 5:  Loss:     1.3418 Validation Accuracy: 0.519400
# Epoch  7, CIFAR-10 Batch 1:  Loss:     1.3335 Validation Accuracy: 0.522800
# Epoch  7, CIFAR-10 Batch 2:  Loss:     1.3430 Validation Accuracy: 0.519400
# Epoch  7, CIFAR-10 Batch 3:  Loss:     1.3298 Validation Accuracy: 0.520200
# Epoch  7, CIFAR-10 Batch 4:  Loss:     1.3270 Validation Accuracy: 0.526800
# Epoch  7, CIFAR-10 Batch 5:  Loss:     1.2967 Validation Accuracy: 0.537000
# Epoch  8, CIFAR-10 Batch 1:  Loss:     1.2935 Validation Accuracy: 0.536600
# Epoch  8, CIFAR-10 Batch 2:  Loss:     1.2955 Validation Accuracy: 0.536000
# Epoch  8, CIFAR-10 Batch 3:  Loss:     1.2841 Validation Accuracy: 0.540800
# Epoch  8, CIFAR-10 Batch 4:  Loss:     1.2836 Validation Accuracy: 0.541600
# Epoch  8, CIFAR-10 Batch 5:  Loss:     1.2580 Validation Accuracy: 0.546600
# Epoch  9, CIFAR-10 Batch 1:  Loss:     1.2494 Validation Accuracy: 0.554200
# Epoch  9, CIFAR-10 Batch 2:  Loss:     1.2488 Validation Accuracy: 0.551400
# Epoch  9, CIFAR-10 Batch 3:  Loss:     1.2383 Validation Accuracy: 0.556400
# Epoch  9, CIFAR-10 Batch 4:  Loss:     1.2467 Validation Accuracy: 0.556200
# Epoch  9, CIFAR-10 Batch 5:  Loss:     1.2259 Validation Accuracy: 0.561400
# Epoch 10, CIFAR-10 Batch 1:  Loss:     1.2170 Validation Accuracy: 0.566000
# Epoch 10, CIFAR-10 Batch 2:  Loss:     1.2138 Validation Accuracy: 0.566000
# Epoch 10, CIFAR-10 Batch 3:  Loss:     1.2027 Validation Accuracy: 0.565800
# Epoch 10, CIFAR-10 Batch 4:  Loss:     1.2130 Validation Accuracy: 0.569000
# Epoch 10, CIFAR-10 Batch 5:  Loss:     1.1921 Validation Accuracy: 0.572400
# Epoch 11, CIFAR-10 Batch 1:  Loss:     1.1903 Validation Accuracy: 0.574600
# Epoch 11, CIFAR-10 Batch 2:  Loss:     1.1826 Validation Accuracy: 0.573000
# Epoch 11, CIFAR-10 Batch 3:  Loss:     1.1678 Validation Accuracy: 0.577000
# Epoch 11, CIFAR-10 Batch 4:  Loss:     1.1818 Validation Accuracy: 0.579200
# Epoch 11, CIFAR-10 Batch 5:  Loss:     1.1519 Validation Accuracy: 0.583600
# Epoch 12, CIFAR-10 Batch 1:  Loss:     1.1561 Validation Accuracy: 0.580400
# Epoch 12, CIFAR-10 Batch 2:  Loss:     1.1509 Validation Accuracy: 0.579800
# Epoch 12, CIFAR-10 Batch 3:  Loss:     1.1453 Validation Accuracy: 0.585600
# Epoch 12, CIFAR-10 Batch 4:  Loss:     1.1616 Validation Accuracy: 0.580400
# Epoch 12, CIFAR-10 Batch 5:  Loss:     1.1356 Validation Accuracy: 0.586600
# Epoch 13, CIFAR-10 Batch 1:  Loss:     1.1289 Validation Accuracy: 0.589200
# Epoch 13, CIFAR-10 Batch 2:  Loss:     1.1264 Validation Accuracy: 0.592200
# Epoch 13, CIFAR-10 Batch 3:  Loss:     1.1190 Validation Accuracy: 0.597000
# Epoch 13, CIFAR-10 Batch 4:  Loss:     1.1342 Validation Accuracy: 0.589800
# Epoch 13, CIFAR-10 Batch 5:  Loss:     1.1004 Validation Accuracy: 0.598600
# Epoch 14, CIFAR-10 Batch 1:  Loss:     1.1039 Validation Accuracy: 0.593600
# Epoch 14, CIFAR-10 Batch 2:  Loss:     1.1019 Validation Accuracy: 0.593800
# Epoch 14, CIFAR-10 Batch 3:  Loss:     1.0985 Validation Accuracy: 0.600200
# Epoch 14, CIFAR-10 Batch 4:  Loss:     1.1149 Validation Accuracy: 0.593400
# Epoch 14, CIFAR-10 Batch 5:  Loss:     1.0801 Validation Accuracy: 0.605800
# Epoch 15, CIFAR-10 Batch 1:  Loss:     1.0823 Validation Accuracy: 0.600400
# Epoch 15, CIFAR-10 Batch 2:  Loss:     1.0797 Validation Accuracy: 0.601800
# Epoch 15, CIFAR-10 Batch 3:  Loss:     1.0733 Validation Accuracy: 0.602600
# Epoch 15, CIFAR-10 Batch 4:  Loss:     1.0959 Validation Accuracy: 0.602600
# Epoch 15, CIFAR-10 Batch 5:  Loss:     1.0594 Validation Accuracy: 0.608200
# Epoch 16, CIFAR-10 Batch 1:  Loss:     1.0589 Validation Accuracy: 0.608400
# Epoch 16, CIFAR-10 Batch 2:  Loss:     1.0562 Validation Accuracy: 0.608400
# Epoch 16, CIFAR-10 Batch 3:  Loss:     1.0550 Validation Accuracy: 0.606400
# Epoch 16, CIFAR-10 Batch 4:  Loss:     1.0797 Validation Accuracy: 0.604200
# Epoch 16, CIFAR-10 Batch 5:  Loss:     1.0425 Validation Accuracy: 0.614000
# Epoch 17, CIFAR-10 Batch 1:  Loss:     1.0490 Validation Accuracy: 0.609000
# Epoch 17, CIFAR-10 Batch 2:  Loss:     1.0517 Validation Accuracy: 0.603800
# Epoch 17, CIFAR-10 Batch 3:  Loss:     1.0460 Validation Accuracy: 0.608400
# Epoch 17, CIFAR-10 Batch 4:  Loss:     1.0553 Validation Accuracy: 0.618000
# Epoch 17, CIFAR-10 Batch 5:  Loss:     1.0286 Validation Accuracy: 0.612000
# Epoch 18, CIFAR-10 Batch 1:  Loss:     1.0269 Validation Accuracy: 0.611600
# Epoch 18, CIFAR-10 Batch 2:  Loss:     1.0224 Validation Accuracy: 0.615600
# Epoch 18, CIFAR-10 Batch 3:  Loss:     1.0185 Validation Accuracy: 0.620000
# Epoch 18, CIFAR-10 Batch 4:  Loss:     1.0398 Validation Accuracy: 0.618200
# Epoch 18, CIFAR-10 Batch 5:  Loss:     1.0076 Validation Accuracy: 0.618000
# Epoch 19, CIFAR-10 Batch 1:  Loss:     1.0141 Validation Accuracy: 0.621600
# Epoch 19, CIFAR-10 Batch 2:  Loss:     1.0006 Validation Accuracy: 0.624800
# Epoch 19, CIFAR-10 Batch 3:  Loss:     0.9933 Validation Accuracy: 0.626600
# Epoch 19, CIFAR-10 Batch 4:  Loss:     1.0212 Validation Accuracy: 0.624600
# Epoch 19, CIFAR-10 Batch 5:  Loss:     0.9842 Validation Accuracy: 0.624400
# Epoch 20, CIFAR-10 Batch 1:  Loss:     0.9905 Validation Accuracy: 0.622200
# Epoch 20, CIFAR-10 Batch 2:  Loss:     0.9891 Validation Accuracy: 0.624400
# Epoch 20, CIFAR-10 Batch 3:  Loss:     0.9839 Validation Accuracy: 0.628200
# Epoch 20, CIFAR-10 Batch 4:  Loss:     1.0042 Validation Accuracy: 0.630000
# Epoch 20, CIFAR-10 Batch 5:  Loss:     0.9762 Validation Accuracy: 0.623800
# Epoch 21, CIFAR-10 Batch 1:  Loss:     0.9793 Validation Accuracy: 0.632400
# Epoch 21, CIFAR-10 Batch 2:  Loss:     0.9683 Validation Accuracy: 0.633800
# Epoch 21, CIFAR-10 Batch 3:  Loss:     0.9646 Validation Accuracy: 0.633600
# Epoch 21, CIFAR-10 Batch 4:  Loss:     0.9863 Validation Accuracy: 0.635600
# Epoch 21, CIFAR-10 Batch 5:  Loss:     0.9509 Validation Accuracy: 0.634800
# Epoch 22, CIFAR-10 Batch 1:  Loss:     0.9616 Validation Accuracy: 0.630600
# Epoch 22, CIFAR-10 Batch 2:  Loss:     0.9564 Validation Accuracy: 0.632200
# Epoch 22, CIFAR-10 Batch 3:  Loss:     0.9483 Validation Accuracy: 0.634600
# Epoch 22, CIFAR-10 Batch 4:  Loss:     0.9686 Validation Accuracy: 0.641000
# Epoch 22, CIFAR-10 Batch 5:  Loss:     0.9390 Validation Accuracy: 0.637000
# Epoch 23, CIFAR-10 Batch 1:  Loss:     0.9495 Validation Accuracy: 0.635400
# Epoch 23, CIFAR-10 Batch 2:  Loss:     0.9463 Validation Accuracy: 0.633400
# Epoch 23, CIFAR-10 Batch 3:  Loss:     0.9402 Validation Accuracy: 0.638800
# Epoch 23, CIFAR-10 Batch 4:  Loss:     0.9586 Validation Accuracy: 0.645400
# Epoch 23, CIFAR-10 Batch 5:  Loss:     0.9289 Validation Accuracy: 0.637600
# Epoch 24, CIFAR-10 Batch 1:  Loss:     0.9357 Validation Accuracy: 0.643200
# Epoch 24, CIFAR-10 Batch 2:  Loss:     0.9320 Validation Accuracy: 0.636200
# Epoch 24, CIFAR-10 Batch 3:  Loss:     0.9323 Validation Accuracy: 0.639000
# Epoch 24, CIFAR-10 Batch 4:  Loss:     0.9494 Validation Accuracy: 0.640400
# Epoch 24, CIFAR-10 Batch 5:  Loss:     0.9064 Validation Accuracy: 0.648200
# Epoch 25, CIFAR-10 Batch 1:  Loss:     0.9196 Validation Accuracy: 0.641000
# Epoch 25, CIFAR-10 Batch 2:  Loss:     0.9260 Validation Accuracy: 0.637600
# Epoch 25, CIFAR-10 Batch 3:  Loss:     0.9327 Validation Accuracy: 0.635000
# Epoch 25, CIFAR-10 Batch 4:  Loss:     0.9582 Validation Accuracy: 0.632000
# Epoch 25, CIFAR-10 Batch 5:  Loss:     0.9217 Validation Accuracy: 0.635800
# Epoch 26, CIFAR-10 Batch 1:  Loss:     0.9196 Validation Accuracy: 0.642000
# Epoch 26, CIFAR-10 Batch 2:  Loss:     0.9103 Validation Accuracy: 0.635600
# Epoch 26, CIFAR-10 Batch 3:  Loss:     0.9098 Validation Accuracy: 0.641600
# Epoch 26, CIFAR-10 Batch 4:  Loss:     0.9228 Validation Accuracy: 0.646800
# Epoch 26, CIFAR-10 Batch 5:  Loss:     0.8838 Validation Accuracy: 0.649600
# Epoch 27, CIFAR-10 Batch 1:  Loss:     0.8898 Validation Accuracy: 0.650400
# Epoch 27, CIFAR-10 Batch 2:  Loss:     0.8827 Validation Accuracy: 0.649800
# Epoch 27, CIFAR-10 Batch 3:  Loss:     0.8840 Validation Accuracy: 0.654200
# Epoch 27, CIFAR-10 Batch 4:  Loss:     0.9046 Validation Accuracy: 0.651400
# Epoch 27, CIFAR-10 Batch 5:  Loss:     0.8691 Validation Accuracy: 0.652000
# Epoch 28, CIFAR-10 Batch 1:  Loss:     0.8767 Validation Accuracy: 0.652800
# Epoch 28, CIFAR-10 Batch 2:  Loss:     0.8711 Validation Accuracy: 0.652000
# Epoch 28, CIFAR-10 Batch 3:  Loss:     0.8748 Validation Accuracy: 0.653800
# Epoch 28, CIFAR-10 Batch 4:  Loss:     0.8944 Validation Accuracy: 0.654200
# Epoch 28, CIFAR-10 Batch 5:  Loss:     0.8640 Validation Accuracy: 0.647200
# Epoch 29, CIFAR-10 Batch 1:  Loss:     0.8691 Validation Accuracy: 0.653600
# Epoch 29, CIFAR-10 Batch 2:  Loss:     0.8588 Validation Accuracy: 0.653600
# Epoch 29, CIFAR-10 Batch 3:  Loss:     0.8579 Validation Accuracy: 0.654000
# Epoch 29, CIFAR-10 Batch 4:  Loss:     0.8836 Validation Accuracy: 0.654400
# Epoch 29, CIFAR-10 Batch 5:  Loss:     0.8537 Validation Accuracy: 0.651200
# Epoch 30, CIFAR-10 Batch 1:  Loss:     0.8601 Validation Accuracy: 0.654800
# Epoch 30, CIFAR-10 Batch 2:  Loss:     0.8489 Validation Accuracy: 0.655200
# Epoch 30, CIFAR-10 Batch 3:  Loss:     0.8459 Validation Accuracy: 0.658200
# Epoch 30, CIFAR-10 Batch 4:  Loss:     0.8711 Validation Accuracy: 0.657400
# Epoch 30, CIFAR-10 Batch 5:  Loss:     0.8355 Validation Accuracy: 0.655200
# Epoch 31, CIFAR-10 Batch 1:  Loss:     0.8419 Validation Accuracy: 0.660000
# Epoch 31, CIFAR-10 Batch 2:  Loss:     0.8340 Validation Accuracy: 0.657200
# Epoch 31, CIFAR-10 Batch 3:  Loss:     0.8391 Validation Accuracy: 0.659800
# Epoch 31, CIFAR-10 Batch 4:  Loss:     0.8659 Validation Accuracy: 0.654400
# Epoch 31, CIFAR-10 Batch 5:  Loss:     0.8283 Validation Accuracy: 0.656000
# Epoch 32, CIFAR-10 Batch 1:  Loss:     0.8332 Validation Accuracy: 0.661400
# Epoch 32, CIFAR-10 Batch 2:  Loss:     0.8198 Validation Accuracy: 0.660200
# Epoch 32, CIFAR-10 Batch 3:  Loss:     0.8209 Validation Accuracy: 0.663600
# Epoch 32, CIFAR-10 Batch 4:  Loss:     0.8481 Validation Accuracy: 0.659200
# Epoch 32, CIFAR-10 Batch 5:  Loss:     0.8153 Validation Accuracy: 0.658200
# Epoch 33, CIFAR-10 Batch 1:  Loss:     0.8259 Validation Accuracy: 0.660800
# Epoch 33, CIFAR-10 Batch 2:  Loss:     0.8098 Validation Accuracy: 0.663200
# Epoch 33, CIFAR-10 Batch 3:  Loss:     0.8094 Validation Accuracy: 0.661600
# Epoch 33, CIFAR-10 Batch 4:  Loss:     0.8341 Validation Accuracy: 0.661600
# Epoch 33, CIFAR-10 Batch 5:  Loss:     0.7976 Validation Accuracy: 0.662800
# Epoch 34, CIFAR-10 Batch 1:  Loss:     0.8072 Validation Accuracy: 0.667200
# Epoch 34, CIFAR-10 Batch 2:  Loss:     0.7972 Validation Accuracy: 0.661800
# Epoch 34, CIFAR-10 Batch 3:  Loss:     0.7996 Validation Accuracy: 0.666000
# Epoch 34, CIFAR-10 Batch 4:  Loss:     0.8226 Validation Accuracy: 0.664000
# Epoch 34, CIFAR-10 Batch 5:  Loss:     0.7864 Validation Accuracy: 0.664200
# Epoch 35, CIFAR-10 Batch 1:  Loss:     0.7973 Validation Accuracy: 0.667800
# Epoch 35, CIFAR-10 Batch 2:  Loss:     0.7870 Validation Accuracy: 0.665600
# Epoch 35, CIFAR-10 Batch 3:  Loss:     0.7869 Validation Accuracy: 0.671800
# Epoch 35, CIFAR-10 Batch 4:  Loss:     0.8100 Validation Accuracy: 0.667200
# Epoch 35, CIFAR-10 Batch 5:  Loss:     0.7750 Validation Accuracy: 0.668400
# Epoch 36, CIFAR-10 Batch 1:  Loss:     0.7868 Validation Accuracy: 0.669800
# Epoch 36, CIFAR-10 Batch 2:  Loss:     0.7845 Validation Accuracy: 0.668400
# Epoch 36, CIFAR-10 Batch 3:  Loss:     0.7781 Validation Accuracy: 0.670000
# Epoch 36, CIFAR-10 Batch 4:  Loss:     0.7995 Validation Accuracy: 0.667800
# Epoch 36, CIFAR-10 Batch 5:  Loss:     0.7667 Validation Accuracy: 0.668800
# Epoch 37, CIFAR-10 Batch 1:  Loss:     0.7754 Validation Accuracy: 0.672400
# Epoch 37, CIFAR-10 Batch 2:  Loss:     0.7659 Validation Accuracy: 0.667000
# Epoch 37, CIFAR-10 Batch 3:  Loss:     0.7678 Validation Accuracy: 0.670200
# Epoch 37, CIFAR-10 Batch 4:  Loss:     0.7900 Validation Accuracy: 0.671600
# Epoch 37, CIFAR-10 Batch 5:  Loss:     0.7518 Validation Accuracy: 0.672400
# Epoch 38, CIFAR-10 Batch 1:  Loss:     0.7624 Validation Accuracy: 0.673800
# Epoch 38, CIFAR-10 Batch 2:  Loss:     0.7560 Validation Accuracy: 0.672400
# Epoch 38, CIFAR-10 Batch 3:  Loss:     0.7588 Validation Accuracy: 0.675600
# Epoch 38, CIFAR-10 Batch 4:  Loss:     0.7825 Validation Accuracy: 0.673400
# Epoch 38, CIFAR-10 Batch 5:  Loss:     0.7537 Validation Accuracy: 0.671000
# Epoch 39, CIFAR-10 Batch 1:  Loss:     0.7538 Validation Accuracy: 0.676800
# Epoch 39, CIFAR-10 Batch 2:  Loss:     0.7457 Validation Accuracy: 0.672800
# Epoch 39, CIFAR-10 Batch 3:  Loss:     0.7569 Validation Accuracy: 0.669800
# Epoch 39, CIFAR-10 Batch 4:  Loss:     0.7747 Validation Accuracy: 0.674800
# Epoch 39, CIFAR-10 Batch 5:  Loss:     0.7385 Validation Accuracy: 0.674400
# Epoch 40, CIFAR-10 Batch 1:  Loss:     0.7442 Validation Accuracy: 0.672800
# Epoch 40, CIFAR-10 Batch 2:  Loss:     0.7373 Validation Accuracy: 0.674600
# Epoch 40, CIFAR-10 Batch 3:  Loss:     0.7388 Validation Accuracy: 0.676800
# Epoch 40, CIFAR-10 Batch 4:  Loss:     0.7583 Validation Accuracy: 0.676400
# Epoch 40, CIFAR-10 Batch 5:  Loss:     0.7317 Validation Accuracy: 0.678400
# Epoch 41, CIFAR-10 Batch 1:  Loss:     0.7421 Validation Accuracy: 0.675800
# Epoch 41, CIFAR-10 Batch 2:  Loss:     0.7247 Validation Accuracy: 0.675200
# Epoch 41, CIFAR-10 Batch 3:  Loss:     0.7260 Validation Accuracy: 0.682800
# Epoch 41, CIFAR-10 Batch 4:  Loss:     0.7502 Validation Accuracy: 0.676600
# Epoch 41, CIFAR-10 Batch 5:  Loss:     0.7136 Validation Accuracy: 0.681200
# Epoch 42, CIFAR-10 Batch 1:  Loss:     0.7251 Validation Accuracy: 0.678600
# Epoch 42, CIFAR-10 Batch 2:  Loss:     0.7155 Validation Accuracy: 0.680800
# Epoch 42, CIFAR-10 Batch 3:  Loss:     0.7139 Validation Accuracy: 0.684400
# Epoch 42, CIFAR-10 Batch 4:  Loss:     0.7476 Validation Accuracy: 0.676200
# Epoch 42, CIFAR-10 Batch 5:  Loss:     0.7029 Validation Accuracy: 0.685600
# Epoch 43, CIFAR-10 Batch 1:  Loss:     0.7157 Validation Accuracy: 0.678000
# Epoch 43, CIFAR-10 Batch 2:  Loss:     0.7068 Validation Accuracy: 0.679400
# Epoch 43, CIFAR-10 Batch 3:  Loss:     0.7058 Validation Accuracy: 0.684200
# Epoch 43, CIFAR-10 Batch 4:  Loss:     0.7324 Validation Accuracy: 0.680600
# Epoch 43, CIFAR-10 Batch 5:  Loss:     0.6950 Validation Accuracy: 0.682200
# Epoch 44, CIFAR-10 Batch 1:  Loss:     0.7094 Validation Accuracy: 0.684000
# Epoch 44, CIFAR-10 Batch 2:  Loss:     0.7021 Validation Accuracy: 0.680400
# Epoch 44, CIFAR-10 Batch 3:  Loss:     0.6963 Validation Accuracy: 0.684000
# Epoch 44, CIFAR-10 Batch 4:  Loss:     0.7279 Validation Accuracy: 0.679400
# Epoch 44, CIFAR-10 Batch 5:  Loss:     0.6896 Validation Accuracy: 0.690000
# Epoch 45, CIFAR-10 Batch 1:  Loss:     0.6979 Validation Accuracy: 0.684000
# Epoch 45, CIFAR-10 Batch 2:  Loss:     0.6829 Validation Accuracy: 0.688600
# Epoch 45, CIFAR-10 Batch 3:  Loss:     0.6871 Validation Accuracy: 0.689400
# Epoch 45, CIFAR-10 Batch 4:  Loss:     0.7111 Validation Accuracy: 0.684800
# Epoch 45, CIFAR-10 Batch 5:  Loss:     0.6789 Validation Accuracy: 0.686800
# Epoch 46, CIFAR-10 Batch 1:  Loss:     0.6917 Validation Accuracy: 0.688600
# Epoch 46, CIFAR-10 Batch 2:  Loss:     0.6769 Validation Accuracy: 0.688200
# Epoch 46, CIFAR-10 Batch 3:  Loss:     0.6799 Validation Accuracy: 0.691400
# Epoch 46, CIFAR-10 Batch 4:  Loss:     0.7055 Validation Accuracy: 0.681600
# Epoch 46, CIFAR-10 Batch 5:  Loss:     0.6708 Validation Accuracy: 0.685000
# Epoch 47, CIFAR-10 Batch 1:  Loss:     0.6832 Validation Accuracy: 0.689800
# Epoch 47, CIFAR-10 Batch 2:  Loss:     0.6677 Validation Accuracy: 0.688000
# Epoch 47, CIFAR-10 Batch 3:  Loss:     0.6684 Validation Accuracy: 0.690200
# Epoch 47, CIFAR-10 Batch 4:  Loss:     0.6955 Validation Accuracy: 0.685400
# Epoch 47, CIFAR-10 Batch 5:  Loss:     0.6634 Validation Accuracy: 0.688800
# Epoch 48, CIFAR-10 Batch 1:  Loss:     0.6696 Validation Accuracy: 0.689600
# Epoch 48, CIFAR-10 Batch 2:  Loss:     0.6563 Validation Accuracy: 0.686600
# Epoch 48, CIFAR-10 Batch 3:  Loss:     0.6612 Validation Accuracy: 0.697400
# Epoch 48, CIFAR-10 Batch 4:  Loss:     0.6844 Validation Accuracy: 0.692000
# Epoch 48, CIFAR-10 Batch 5:  Loss:     0.6474 Validation Accuracy: 0.695200
# Epoch 49, CIFAR-10 Batch 1:  Loss:     0.6653 Validation Accuracy: 0.694000
# Epoch 49, CIFAR-10 Batch 2:  Loss:     0.6541 Validation Accuracy: 0.694800
# Epoch 49, CIFAR-10 Batch 3:  Loss:     0.6528 Validation Accuracy: 0.695000
# Epoch 49, CIFAR-10 Batch 4:  Loss:     0.6820 Validation Accuracy: 0.687800
# Epoch 49, CIFAR-10 Batch 5:  Loss:     0.6402 Validation Accuracy: 0.694400
# Epoch 50, CIFAR-10 Batch 1:  Loss:     0.6480 Validation Accuracy: 0.695000
# Epoch 50, CIFAR-10 Batch 2:  Loss:     0.6386 Validation Accuracy: 0.688400
# Epoch 50, CIFAR-10 Batch 3:  Loss:     0.6415 Validation Accuracy: 0.697600
# Epoch 50, CIFAR-10 Batch 4:  Loss:     0.6653 Validation Accuracy: 0.693200
# Epoch 50, CIFAR-10 Batch 5:  Loss:     0.6304 Validation Accuracy: 0.696200
# Epoch 51, CIFAR-10 Batch 1:  Loss:     0.6480 Validation Accuracy: 0.693400
# Epoch 51, CIFAR-10 Batch 2:  Loss:     0.6348 Validation Accuracy: 0.696200
# Epoch 51, CIFAR-10 Batch 3:  Loss:     0.6318 Validation Accuracy: 0.700000
# Epoch 51, CIFAR-10 Batch 4:  Loss:     0.6585 Validation Accuracy: 0.692800
# Epoch 51, CIFAR-10 Batch 5:  Loss:     0.6221 Validation Accuracy: 0.696600
# Epoch 52, CIFAR-10 Batch 1:  Loss:     0.6352 Validation Accuracy: 0.698000
# Epoch 52, CIFAR-10 Batch 2:  Loss:     0.6241 Validation Accuracy: 0.697200
# Epoch 52, CIFAR-10 Batch 3:  Loss:     0.6262 Validation Accuracy: 0.700800
# Epoch 52, CIFAR-10 Batch 4:  Loss:     0.6542 Validation Accuracy: 0.690000
# Epoch 52, CIFAR-10 Batch 5:  Loss:     0.6172 Validation Accuracy: 0.704600
# Epoch 53, CIFAR-10 Batch 1:  Loss:     0.6230 Validation Accuracy: 0.699400
# Epoch 53, CIFAR-10 Batch 2:  Loss:     0.6142 Validation Accuracy: 0.697800
# Epoch 53, CIFAR-10 Batch 3:  Loss:     0.6171 Validation Accuracy: 0.703200
# Epoch 53, CIFAR-10 Batch 4:  Loss:     0.6386 Validation Accuracy: 0.695200
# Epoch 53, CIFAR-10 Batch 5:  Loss:     0.6040 Validation Accuracy: 0.703800
# Epoch 54, CIFAR-10 Batch 1:  Loss:     0.6162 Validation Accuracy: 0.701200
# Epoch 54, CIFAR-10 Batch 2:  Loss:     0.6045 Validation Accuracy: 0.700600
# Epoch 54, CIFAR-10 Batch 3:  Loss:     0.6080 Validation Accuracy: 0.701800
# Epoch 54, CIFAR-10 Batch 4:  Loss:     0.6282 Validation Accuracy: 0.698400
# Epoch 54, CIFAR-10 Batch 5:  Loss:     0.5929 Validation Accuracy: 0.705600
# Epoch 55, CIFAR-10 Batch 1:  Loss:     0.6085 Validation Accuracy: 0.701000
# Epoch 55, CIFAR-10 Batch 2:  Loss:     0.5960 Validation Accuracy: 0.700800
# Epoch 55, CIFAR-10 Batch 3:  Loss:     0.6041 Validation Accuracy: 0.703200
# Epoch 55, CIFAR-10 Batch 4:  Loss:     0.6223 Validation Accuracy: 0.695000
# Epoch 55, CIFAR-10 Batch 5:  Loss:     0.5864 Validation Accuracy: 0.705000
# Epoch 56, CIFAR-10 Batch 1:  Loss:     0.5990 Validation Accuracy: 0.704600
# Epoch 56, CIFAR-10 Batch 2:  Loss:     0.5947 Validation Accuracy: 0.697600
# Epoch 56, CIFAR-10 Batch 3:  Loss:     0.5914 Validation Accuracy: 0.707800
# Epoch 56, CIFAR-10 Batch 4:  Loss:     0.6177 Validation Accuracy: 0.698000
# Epoch 56, CIFAR-10 Batch 5:  Loss:     0.5735 Validation Accuracy: 0.700800
# Epoch 57, CIFAR-10 Batch 1:  Loss:     0.5890 Validation Accuracy: 0.706600
# Epoch 57, CIFAR-10 Batch 2:  Loss:     0.5860 Validation Accuracy: 0.702000
# Epoch 57, CIFAR-10 Batch 3:  Loss:     0.5842 Validation Accuracy: 0.710800
# Epoch 57, CIFAR-10 Batch 4:  Loss:     0.6059 Validation Accuracy: 0.701800
# Epoch 57, CIFAR-10 Batch 5:  Loss:     0.5707 Validation Accuracy: 0.706200
# Epoch 58, CIFAR-10 Batch 1:  Loss:     0.5816 Validation Accuracy: 0.712800
# Epoch 58, CIFAR-10 Batch 2:  Loss:     0.5799 Validation Accuracy: 0.698800
# Epoch 58, CIFAR-10 Batch 3:  Loss:     0.5776 Validation Accuracy: 0.708200
# Epoch 58, CIFAR-10 Batch 4:  Loss:     0.5959 Validation Accuracy: 0.704400
# Epoch 58, CIFAR-10 Batch 5:  Loss:     0.5628 Validation Accuracy: 0.707600
# Epoch 59, CIFAR-10 Batch 1:  Loss:     0.5807 Validation Accuracy: 0.710600
# Epoch 59, CIFAR-10 Batch 2:  Loss:     0.5760 Validation Accuracy: 0.698800
# Epoch 59, CIFAR-10 Batch 3:  Loss:     0.5717 Validation Accuracy: 0.707000
# Epoch 59, CIFAR-10 Batch 4:  Loss:     0.5906 Validation Accuracy: 0.700800
# Epoch 59, CIFAR-10 Batch 5:  Loss:     0.5454 Validation Accuracy: 0.710600
# Epoch 60, CIFAR-10 Batch 1:  Loss:     0.5731 Validation Accuracy: 0.708200
# Epoch 60, CIFAR-10 Batch 2:  Loss:     0.5742 Validation Accuracy: 0.695800
# Epoch 60, CIFAR-10 Batch 3:  Loss:     0.5699 Validation Accuracy: 0.704200
# Epoch 60, CIFAR-10 Batch 4:  Loss:     0.5850 Validation Accuracy: 0.706200
# Epoch 60, CIFAR-10 Batch 5:  Loss:     0.5602 Validation Accuracy: 0.701400
# Epoch 61, CIFAR-10 Batch 1:  Loss:     0.5747 Validation Accuracy: 0.711200
# Epoch 61, CIFAR-10 Batch 2:  Loss:     0.5653 Validation Accuracy: 0.697000
# Epoch 61, CIFAR-10 Batch 3:  Loss:     0.5479 Validation Accuracy: 0.710800
# Epoch 61, CIFAR-10 Batch 4:  Loss:     0.5719 Validation Accuracy: 0.712800
# Epoch 61, CIFAR-10 Batch 5:  Loss:     0.5504 Validation Accuracy: 0.700800
# Epoch 62, CIFAR-10 Batch 1:  Loss:     0.5724 Validation Accuracy: 0.704400
# Epoch 62, CIFAR-10 Batch 2:  Loss:     0.5486 Validation Accuracy: 0.708800
# Epoch 62, CIFAR-10 Batch 3:  Loss:     0.5505 Validation Accuracy: 0.699800
# Epoch 62, CIFAR-10 Batch 4:  Loss:     0.5829 Validation Accuracy: 0.712000
# Epoch 62, CIFAR-10 Batch 5:  Loss:     0.5390 Validation Accuracy: 0.706400
# Epoch 63, CIFAR-10 Batch 1:  Loss:     0.5430 Validation Accuracy: 0.711400
# Epoch 63, CIFAR-10 Batch 2:  Loss:     0.5404 Validation Accuracy: 0.713600
# Epoch 63, CIFAR-10 Batch 3:  Loss:     0.5403 Validation Accuracy: 0.703600
# Epoch 63, CIFAR-10 Batch 4:  Loss:     0.5570 Validation Accuracy: 0.715800
# Epoch 63, CIFAR-10 Batch 5:  Loss:     0.5257 Validation Accuracy: 0.711800
# Epoch 64, CIFAR-10 Batch 1:  Loss:     0.5455 Validation Accuracy: 0.706800
# Epoch 64, CIFAR-10 Batch 2:  Loss:     0.5288 Validation Accuracy: 0.714000
# Epoch 64, CIFAR-10 Batch 3:  Loss:     0.5228 Validation Accuracy: 0.714000
# Epoch 64, CIFAR-10 Batch 4:  Loss:     0.5451 Validation Accuracy: 0.714200
# Epoch 64, CIFAR-10 Batch 5:  Loss:     0.5114 Validation Accuracy: 0.714800
# Epoch 65, CIFAR-10 Batch 1:  Loss:     0.5250 Validation Accuracy: 0.715800
# Epoch 65, CIFAR-10 Batch 2:  Loss:     0.5140 Validation Accuracy: 0.717400
# Epoch 65, CIFAR-10 Batch 3:  Loss:     0.5113 Validation Accuracy: 0.717200
# Epoch 65, CIFAR-10 Batch 4:  Loss:     0.5320 Validation Accuracy: 0.716800
# Epoch 65, CIFAR-10 Batch 5:  Loss:     0.4993 Validation Accuracy: 0.715200
# Epoch 66, CIFAR-10 Batch 1:  Loss:     0.5186 Validation Accuracy: 0.718200
# Epoch 66, CIFAR-10 Batch 2:  Loss:     0.5207 Validation Accuracy: 0.708200
# Epoch 66, CIFAR-10 Batch 3:  Loss:     0.5164 Validation Accuracy: 0.710000
# Epoch 66, CIFAR-10 Batch 4:  Loss:     0.5442 Validation Accuracy: 0.707400
# Epoch 66, CIFAR-10 Batch 5:  Loss:     0.5044 Validation Accuracy: 0.713600
# Epoch 67, CIFAR-10 Batch 1:  Loss:     0.5144 Validation Accuracy: 0.718600
# Epoch 67, CIFAR-10 Batch 2:  Loss:     0.5019 Validation Accuracy: 0.714400
# Epoch 67, CIFAR-10 Batch 3:  Loss:     0.4968 Validation Accuracy: 0.712800
# Epoch 67, CIFAR-10 Batch 4:  Loss:     0.5228 Validation Accuracy: 0.720200
# Epoch 67, CIFAR-10 Batch 5:  Loss:     0.4942 Validation Accuracy: 0.714000
# Epoch 68, CIFAR-10 Batch 1:  Loss:     0.5207 Validation Accuracy: 0.717400
# Epoch 68, CIFAR-10 Batch 2:  Loss:     0.5014 Validation Accuracy: 0.715200
# Epoch 68, CIFAR-10 Batch 3:  Loss:     0.4986 Validation Accuracy: 0.709200
# Epoch 68, CIFAR-10 Batch 4:  Loss:     0.5275 Validation Accuracy: 0.715600
# Epoch 68, CIFAR-10 Batch 5:  Loss:     0.4893 Validation Accuracy: 0.717000
# Epoch 69, CIFAR-10 Batch 1:  Loss:     0.4952 Validation Accuracy: 0.721400
# Epoch 69, CIFAR-10 Batch 2:  Loss:     0.4876 Validation Accuracy: 0.718000
# Epoch 69, CIFAR-10 Batch 3:  Loss:     0.4885 Validation Accuracy: 0.710200
# Epoch 69, CIFAR-10 Batch 4:  Loss:     0.5119 Validation Accuracy: 0.718800
# Epoch 69, CIFAR-10 Batch 5:  Loss:     0.4813 Validation Accuracy: 0.713800
# Epoch 70, CIFAR-10 Batch 1:  Loss:     0.5031 Validation Accuracy: 0.716400
# Epoch 70, CIFAR-10 Batch 2:  Loss:     0.4865 Validation Accuracy: 0.719200
# Epoch 70, CIFAR-10 Batch 3:  Loss:     0.4792 Validation Accuracy: 0.715400
# Epoch 70, CIFAR-10 Batch 4:  Loss:     0.5037 Validation Accuracy: 0.719400
# Epoch 70, CIFAR-10 Batch 5:  Loss:     0.4715 Validation Accuracy: 0.721200
# Epoch 71, CIFAR-10 Batch 1:  Loss:     0.4852 Validation Accuracy: 0.721600
# Epoch 71, CIFAR-10 Batch 2:  Loss:     0.4750 Validation Accuracy: 0.720800
# Epoch 71, CIFAR-10 Batch 3:  Loss:     0.4685 Validation Accuracy: 0.714800
# Epoch 71, CIFAR-10 Batch 4:  Loss:     0.4870 Validation Accuracy: 0.724000
# Epoch 71, CIFAR-10 Batch 5:  Loss:     0.4562 Validation Accuracy: 0.721000
# Epoch 72, CIFAR-10 Batch 1:  Loss:     0.4731 Validation Accuracy: 0.719400
# Epoch 72, CIFAR-10 Batch 2:  Loss:     0.4679 Validation Accuracy: 0.721600
# Epoch 72, CIFAR-10 Batch 3:  Loss:     0.4636 Validation Accuracy: 0.713200
# Epoch 72, CIFAR-10 Batch 4:  Loss:     0.4791 Validation Accuracy: 0.721000
# Epoch 72, CIFAR-10 Batch 5:  Loss:     0.4530 Validation Accuracy: 0.719200
# Epoch 73, CIFAR-10 Batch 1:  Loss:     0.4705 Validation Accuracy: 0.721200
# Epoch 73, CIFAR-10 Batch 2:  Loss:     0.4685 Validation Accuracy: 0.720800
# Epoch 73, CIFAR-10 Batch 3:  Loss:     0.4602 Validation Accuracy: 0.715000
# Epoch 73, CIFAR-10 Batch 4:  Loss:     0.4716 Validation Accuracy: 0.723000
# Epoch 73, CIFAR-10 Batch 5:  Loss:     0.4457 Validation Accuracy: 0.723400
# Epoch 74, CIFAR-10 Batch 1:  Loss:     0.4645 Validation Accuracy: 0.720800
# Epoch 74, CIFAR-10 Batch 2:  Loss:     0.4675 Validation Accuracy: 0.718200
# Epoch 74, CIFAR-10 Batch 3:  Loss:     0.4674 Validation Accuracy: 0.709600
# Epoch 74, CIFAR-10 Batch 4:  Loss:     0.4875 Validation Accuracy: 0.713600
# Epoch 74, CIFAR-10 Batch 5:  Loss:     0.4591 Validation Accuracy: 0.710400
# Epoch 75, CIFAR-10 Batch 1:  Loss:     0.4623 Validation Accuracy: 0.721000
# Epoch 75, CIFAR-10 Batch 2:  Loss:     0.4511 Validation Accuracy: 0.723400
# Epoch 75, CIFAR-10 Batch 3:  Loss:     0.4431 Validation Accuracy: 0.719800
# Epoch 75, CIFAR-10 Batch 4:  Loss:     0.4645 Validation Accuracy: 0.724000
# Epoch 75, CIFAR-10 Batch 5:  Loss:     0.4409 Validation Accuracy: 0.716800
# Epoch 76, CIFAR-10 Batch 1:  Loss:     0.4481 Validation Accuracy: 0.724800
# Epoch 76, CIFAR-10 Batch 2:  Loss:     0.4536 Validation Accuracy: 0.716600
# Epoch 76, CIFAR-10 Batch 3:  Loss:     0.4408 Validation Accuracy: 0.724400
# Epoch 76, CIFAR-10 Batch 4:  Loss:     0.4555 Validation Accuracy: 0.721600
# Epoch 76, CIFAR-10 Batch 5:  Loss:     0.4314 Validation Accuracy: 0.719800
# Epoch 77, CIFAR-10 Batch 1:  Loss:     0.4451 Validation Accuracy: 0.724000
# Epoch 77, CIFAR-10 Batch 2:  Loss:     0.4357 Validation Accuracy: 0.718600
# Epoch 77, CIFAR-10 Batch 3:  Loss:     0.4274 Validation Accuracy: 0.723800
# Epoch 77, CIFAR-10 Batch 4:  Loss:     0.4444 Validation Accuracy: 0.728200
# Epoch 77, CIFAR-10 Batch 5:  Loss:     0.4188 Validation Accuracy: 0.723000
# Epoch 78, CIFAR-10 Batch 1:  Loss:     0.4340 Validation Accuracy: 0.725800
# Epoch 78, CIFAR-10 Batch 2:  Loss:     0.4234 Validation Accuracy: 0.722800
# Epoch 78, CIFAR-10 Batch 3:  Loss:     0.4191 Validation Accuracy: 0.726400
# Epoch 78, CIFAR-10 Batch 4:  Loss:     0.4361 Validation Accuracy: 0.726600
# Epoch 78, CIFAR-10 Batch 5:  Loss:     0.4208 Validation Accuracy: 0.723200
# Epoch 79, CIFAR-10 Batch 1:  Loss:     0.4431 Validation Accuracy: 0.723000
# Epoch 79, CIFAR-10 Batch 2:  Loss:     0.4293 Validation Accuracy: 0.719600
# Epoch 79, CIFAR-10 Batch 3:  Loss:     0.4184 Validation Accuracy: 0.726200
# Epoch 79, CIFAR-10 Batch 4:  Loss:     0.4279 Validation Accuracy: 0.724000
# Epoch 79, CIFAR-10 Batch 5:  Loss:     0.4040 Validation Accuracy: 0.725200
# Epoch 80, CIFAR-10 Batch 1:  Loss:     0.4180 Validation Accuracy: 0.726200
# Epoch 80, CIFAR-10 Batch 2:  Loss:     0.4121 Validation Accuracy: 0.721800
# Epoch 80, CIFAR-10 Batch 3:  Loss:     0.4123 Validation Accuracy: 0.727000
# Epoch 80, CIFAR-10 Batch 4:  Loss:     0.4255 Validation Accuracy: 0.723800
# Epoch 80, CIFAR-10 Batch 5:  Loss:     0.4009 Validation Accuracy: 0.725600
# Epoch 81, CIFAR-10 Batch 1:  Loss:     0.4089 Validation Accuracy: 0.728800
# Epoch 81, CIFAR-10 Batch 2:  Loss:     0.4019 Validation Accuracy: 0.724600
# Epoch 81, CIFAR-10 Batch 3:  Loss:     0.3978 Validation Accuracy: 0.730200
# Epoch 81, CIFAR-10 Batch 4:  Loss:     0.4158 Validation Accuracy: 0.727400
# Epoch 81, CIFAR-10 Batch 5:  Loss:     0.3929 Validation Accuracy: 0.723200
# Epoch 82, CIFAR-10 Batch 1:  Loss:     0.4110 Validation Accuracy: 0.726200
# Epoch 82, CIFAR-10 Batch 2:  Loss:     0.4029 Validation Accuracy: 0.720800
# Epoch 82, CIFAR-10 Batch 3:  Loss:     0.3966 Validation Accuracy: 0.727400
# Epoch 82, CIFAR-10 Batch 4:  Loss:     0.4098 Validation Accuracy: 0.726400
# Epoch 82, CIFAR-10 Batch 5:  Loss:     0.3858 Validation Accuracy: 0.726400
# Epoch 83, CIFAR-10 Batch 1:  Loss:     0.4023 Validation Accuracy: 0.726400
# Epoch 83, CIFAR-10 Batch 2:  Loss:     0.3980 Validation Accuracy: 0.724200
# Epoch 83, CIFAR-10 Batch 3:  Loss:     0.3924 Validation Accuracy: 0.730200
# Epoch 83, CIFAR-10 Batch 4:  Loss:     0.4005 Validation Accuracy: 0.731000
# Epoch 83, CIFAR-10 Batch 5:  Loss:     0.3764 Validation Accuracy: 0.722400
# Epoch 84, CIFAR-10 Batch 1:  Loss:     0.3919 Validation Accuracy: 0.728800
# Epoch 84, CIFAR-10 Batch 2:  Loss:     0.3830 Validation Accuracy: 0.724600
# Epoch 84, CIFAR-10 Batch 3:  Loss:     0.3826 Validation Accuracy: 0.725000
# Epoch 84, CIFAR-10 Batch 4:  Loss:     0.3935 Validation Accuracy: 0.725600
# Epoch 84, CIFAR-10 Batch 5:  Loss:     0.3707 Validation Accuracy: 0.727800
# Epoch 85, CIFAR-10 Batch 1:  Loss:     0.3829 Validation Accuracy: 0.728000
# Epoch 85, CIFAR-10 Batch 2:  Loss:     0.3783 Validation Accuracy: 0.727600
# Epoch 85, CIFAR-10 Batch 3:  Loss:     0.3736 Validation Accuracy: 0.729000
# Epoch 85, CIFAR-10 Batch 4:  Loss:     0.3854 Validation Accuracy: 0.734000
# Epoch 85, CIFAR-10 Batch 5:  Loss:     0.3639 Validation Accuracy: 0.731000
# Epoch 86, CIFAR-10 Batch 1:  Loss:     0.3753 Validation Accuracy: 0.731400
# Epoch 86, CIFAR-10 Batch 2:  Loss:     0.3679 Validation Accuracy: 0.728800
# Epoch 86, CIFAR-10 Batch 3:  Loss:     0.3628 Validation Accuracy: 0.729400
# Epoch 86, CIFAR-10 Batch 4:  Loss:     0.3804 Validation Accuracy: 0.731400
# Epoch 86, CIFAR-10 Batch 5:  Loss:     0.3538 Validation Accuracy: 0.728800
# Epoch 87, CIFAR-10 Batch 1:  Loss:     0.3671 Validation Accuracy: 0.733600
# Epoch 87, CIFAR-10 Batch 2:  Loss:     0.3656 Validation Accuracy: 0.727600
# Epoch 87, CIFAR-10 Batch 3:  Loss:     0.3664 Validation Accuracy: 0.729200
# Epoch 87, CIFAR-10 Batch 4:  Loss:     0.3740 Validation Accuracy: 0.730600
# Epoch 87, CIFAR-10 Batch 5:  Loss:     0.3541 Validation Accuracy: 0.728600
# Epoch 88, CIFAR-10 Batch 1:  Loss:     0.3670 Validation Accuracy: 0.730200
# Epoch 88, CIFAR-10 Batch 2:  Loss:     0.3551 Validation Accuracy: 0.732600
# Epoch 88, CIFAR-10 Batch 3:  Loss:     0.3542 Validation Accuracy: 0.731400
# Epoch 88, CIFAR-10 Batch 4:  Loss:     0.3662 Validation Accuracy: 0.731200
# Epoch 88, CIFAR-10 Batch 5:  Loss:     0.3427 Validation Accuracy: 0.734200
# Epoch 89, CIFAR-10 Batch 1:  Loss:     0.3564 Validation Accuracy: 0.735400
# Epoch 89, CIFAR-10 Batch 2:  Loss:     0.3481 Validation Accuracy: 0.728600
# Epoch 89, CIFAR-10 Batch 3:  Loss:     0.3445 Validation Accuracy: 0.733600
# Epoch 89, CIFAR-10 Batch 4:  Loss:     0.3536 Validation Accuracy: 0.727600
# Epoch 89, CIFAR-10 Batch 5:  Loss:     0.3344 Validation Accuracy: 0.732600
# Epoch 90, CIFAR-10 Batch 1:  Loss:     0.3516 Validation Accuracy: 0.728600
# Epoch 90, CIFAR-10 Batch 2:  Loss:     0.3466 Validation Accuracy: 0.724800
# Epoch 90, CIFAR-10 Batch 3:  Loss:     0.3445 Validation Accuracy: 0.731000
# Epoch 90, CIFAR-10 Batch 4:  Loss:     0.3549 Validation Accuracy: 0.729600
# Epoch 90, CIFAR-10 Batch 5:  Loss:     0.3376 Validation Accuracy: 0.727600
# Epoch 91, CIFAR-10 Batch 1:  Loss:     0.3517 Validation Accuracy: 0.728600
# Epoch 91, CIFAR-10 Batch 2:  Loss:     0.3476 Validation Accuracy: 0.726000
# Epoch 91, CIFAR-10 Batch 3:  Loss:     0.3421 Validation Accuracy: 0.732000
# Epoch 91, CIFAR-10 Batch 4:  Loss:     0.3444 Validation Accuracy: 0.733400
# Epoch 91, CIFAR-10 Batch 5:  Loss:     0.3263 Validation Accuracy: 0.735000
# Epoch 92, CIFAR-10 Batch 1:  Loss:     0.3391 Validation Accuracy: 0.730800
# Epoch 92, CIFAR-10 Batch 2:  Loss:     0.3399 Validation Accuracy: 0.727400
# Epoch 92, CIFAR-10 Batch 3:  Loss:     0.3408 Validation Accuracy: 0.729400
# Epoch 92, CIFAR-10 Batch 4:  Loss:     0.3449 Validation Accuracy: 0.729200
# Epoch 92, CIFAR-10 Batch 5:  Loss:     0.3183 Validation Accuracy: 0.734000
# Epoch 93, CIFAR-10 Batch 1:  Loss:     0.3271 Validation Accuracy: 0.732800
# Epoch 93, CIFAR-10 Batch 2:  Loss:     0.3204 Validation Accuracy: 0.731000
# Epoch 93, CIFAR-10 Batch 3:  Loss:     0.3271 Validation Accuracy: 0.736600
# Epoch 93, CIFAR-10 Batch 4:  Loss:     0.3413 Validation Accuracy: 0.731600
# Epoch 93, CIFAR-10 Batch 5:  Loss:     0.3173 Validation Accuracy: 0.731600
# Epoch 94, CIFAR-10 Batch 1:  Loss:     0.3234 Validation Accuracy: 0.735600
# Epoch 94, CIFAR-10 Batch 2:  Loss:     0.3140 Validation Accuracy: 0.735000
# Epoch 94, CIFAR-10 Batch 3:  Loss:     0.3169 Validation Accuracy: 0.732200
# Epoch 94, CIFAR-10 Batch 4:  Loss:     0.3315 Validation Accuracy: 0.730000
# Epoch 94, CIFAR-10 Batch 5:  Loss:     0.3092 Validation Accuracy: 0.733200
# Epoch 95, CIFAR-10 Batch 1:  Loss:     0.3200 Validation Accuracy: 0.733200
# Epoch 95, CIFAR-10 Batch 2:  Loss:     0.3126 Validation Accuracy: 0.730400
# Epoch 95, CIFAR-10 Batch 3:  Loss:     0.3176 Validation Accuracy: 0.730000
# Epoch 95, CIFAR-10 Batch 4:  Loss:     0.3232 Validation Accuracy: 0.732400
# Epoch 95, CIFAR-10 Batch 5:  Loss:     0.3019 Validation Accuracy: 0.734800
# Epoch 96, CIFAR-10 Batch 1:  Loss:     0.3148 Validation Accuracy: 0.735200
# Epoch 96, CIFAR-10 Batch 2:  Loss:     0.3065 Validation Accuracy: 0.732800
# Epoch 96, CIFAR-10 Batch 3:  Loss:     0.3058 Validation Accuracy: 0.733000
# Epoch 96, CIFAR-10 Batch 4:  Loss:     0.3143 Validation Accuracy: 0.734600
# Epoch 96, CIFAR-10 Batch 5:  Loss:     0.2974 Validation Accuracy: 0.732600
# Epoch 97, CIFAR-10 Batch 1:  Loss:     0.3082 Validation Accuracy: 0.735400
# Epoch 97, CIFAR-10 Batch 2:  Loss:     0.2995 Validation Accuracy: 0.734800
# Epoch 97, CIFAR-10 Batch 3:  Loss:     0.2994 Validation Accuracy: 0.734400
# Epoch 97, CIFAR-10 Batch 4:  Loss:     0.3086 Validation Accuracy: 0.738000
# Epoch 97, CIFAR-10 Batch 5:  Loss:     0.2882 Validation Accuracy: 0.735400
# Epoch 98, CIFAR-10 Batch 1:  Loss:     0.3014 Validation Accuracy: 0.736400
# Epoch 98, CIFAR-10 Batch 2:  Loss:     0.2931 Validation Accuracy: 0.736400
# Epoch 98, CIFAR-10 Batch 3:  Loss:     0.2982 Validation Accuracy: 0.733400
# Epoch 98, CIFAR-10 Batch 4:  Loss:     0.3165 Validation Accuracy: 0.734400
# Epoch 98, CIFAR-10 Batch 5:  Loss:     0.2888 Validation Accuracy: 0.731800
# Epoch 99, CIFAR-10 Batch 1:  Loss:     0.3014 Validation Accuracy: 0.739200
# Epoch 99, CIFAR-10 Batch 2:  Loss:     0.2872 Validation Accuracy: 0.738200
# Epoch 99, CIFAR-10 Batch 3:  Loss:     0.2890 Validation Accuracy: 0.735200
# Epoch 99, CIFAR-10 Batch 4:  Loss:     0.3000 Validation Accuracy: 0.735000
# Epoch 99, CIFAR-10 Batch 5:  Loss:     0.2761 Validation Accuracy: 0.737200
# Epoch 100, CIFAR-10 Batch 1:  Loss:     0.2882 Validation Accuracy: 0.737200
# Epoch 100, CIFAR-10 Batch 2:  Loss:     0.2784 Validation Accuracy: 0.738400
# Epoch 100, CIFAR-10 Batch 3:  Loss:     0.2860 Validation Accuracy: 0.735000
# Epoch 100, CIFAR-10 Batch 4:  Loss:     0.2963 Validation Accuracy: 0.730400
# Epoch 100, CIFAR-10 Batch 5:  Loss:     0.2726 Validation Accuracy: 0.737400

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.7303998470306396

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
